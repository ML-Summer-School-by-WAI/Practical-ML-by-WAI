# %%
# !unzip "/content/Wai Final.zip"
# Out:
# Archive:  /content/Wai Final.zip
#    creating: Wai Final/
#    creating: Wai Final/data_annotated/
#   inflating: Wai Final/data_annotated/cat.2366.jpg
#   inflating: Wai Final/data_annotated/cat.2366.json
#   inflating: Wai Final/data_annotated/cat.2367.jpg
#   inflating: Wai Final/data_annotated/cat.2367.json
#   inflating: Wai Final/data_annotated/cat.2368.jpg
#   inflating: Wai Final/data_annotated/cat.2368.json
#   inflating: Wai Final/data_annotated/cat.2369.jpg
#   inflating: Wai Final/data_annotated/cat.2369.json
#   inflating: Wai Final/data_annotated/cat.2370.jpg
#   inflating: Wai Final/data_annotated/cat.2370.json
#   inflating: Wai Final/data_annotated/cat.2371.jpg
#   inflating: Wai Final/data_annotated/cat.2371.json
#   inflating: Wai Final/data_annotated/cat.2372.jpg
#   inflating: Wai Final/data_annotated/cat.2372.json
#   inflating: Wai Final/data_annotated/cat.2373.jpg
#   inflating: Wai Final/data_annotated/cat.2373.json
#   inflating: Wai Final/data_annotated/cat.2374.jpg
#   inflating: Wai Final/data_annotated/cat.2374.json
#   inflating: Wai Final/data_annotated/cat.2375.jpg
#   inflating: Wai Final/data_annotated/cat.2375.json
#   inflating: Wai Final/data_annotated/cat.2376.jpg
#   inflating: Wai Final/data_annotated/cat.2376.json
#   inflating: Wai Final/data_annotated/cat.2377.jpg
#   inflating: Wai Final/data_annotated/cat.2377.json
#   inflating: Wai Final/data_annotated/cat.2378.jpg
#   inflating: Wai Final/data_annotated/cat.2378.json
#   inflating: Wai Final/data_annotated/cat.2379.jpg
#   inflating: Wai Final/data_annotated/cat.2379.json
#   inflating: Wai Final/data_annotated/cat.2380.jpg
#   inflating: Wai Final/data_annotated/cat.2380.json
#   inflating: Wai Final/data_annotated/cat.2381.jpg
#   inflating: Wai Final/data_annotated/cat.2381.json
#   inflating: Wai Final/data_annotated/cat.2382.jpg
#   inflating: Wai Final/data_annotated/cat.2382.json
#   inflating: Wai Final/data_annotated/cat.2383.jpg
#   inflating: Wai Final/data_annotated/cat.2383.json
#   inflating: Wai Final/data_annotated/cat.2384.jpg
#   inflating: Wai Final/data_annotated/cat.2384.json
#   inflating: Wai Final/data_annotated/cat.2385.jpg
#   inflating: Wai Final/data_annotated/cat.2385.json
#   inflating: Wai Final/data_annotated/cat.2386.jpg
#   inflating: Wai Final/data_annotated/cat.2386.json
#   inflating: Wai Final/data_annotated/cat.2387.jpg
#   inflating: Wai Final/data_annotated/cat.2387.json
#   inflating: Wai Final/data_annotated/cat.2388.jpg
#   inflating: Wai Final/data_annotated/cat.2388.json
#   inflating: Wai Final/data_annotated/cat.2389.jpg
#   inflating: Wai Final/data_annotated/cat.2389.json
#   inflating: Wai Final/data_annotated/cat.2390.jpg
#   inflating: Wai Final/data_annotated/cat.2390.json
#   inflating: Wai Final/data_annotated/cat.2391.jpg
#   inflating: Wai Final/data_annotated/cat.2391.json
#   inflating: Wai Final/data_annotated/cat.2392.jpg
#   inflating: Wai Final/data_annotated/cat.2392.json
#   inflating: Wai Final/data_annotated/cat.2393.jpg
#   inflating: Wai Final/data_annotated/cat.2393.json
#   inflating: Wai Final/data_annotated/cat.2394.jpg
#   inflating: Wai Final/data_annotated/cat.2394.json
#   inflating: Wai Final/data_annotated/cat.2395.jpg
#   inflating: Wai Final/data_annotated/cat.2395.json
#   inflating: Wai Final/data_annotated/cat.2396.jpg
#   inflating: Wai Final/data_annotated/cat.2396.json
#   inflating: Wai Final/data_annotated/cat.2397.jpg
#   inflating: Wai Final/data_annotated/cat.2397.json
#   inflating: Wai Final/data_annotated/cat.2398.jpg
#   inflating: Wai Final/data_annotated/cat.2398.json
#   inflating: Wai Final/data_annotated/cat.2399.jpg
#   inflating: Wai Final/data_annotated/cat.2399.json
#   inflating: Wai Final/data_annotated/cat.2400.jpg
#   inflating: Wai Final/data_annotated/cat.2400.json
#   inflating: Wai Final/data_annotated/cat.2401.jpg
#   inflating: Wai Final/data_annotated/cat.2401.json
#   inflating: Wai Final/data_annotated/cat.2402.jpg
#   inflating: Wai Final/data_annotated/cat.2402.json
#   inflating: Wai Final/data_annotated/cat.2403.jpg
#   inflating: Wai Final/data_annotated/cat.2403.json
#   inflating: Wai Final/data_annotated/cat.2404.jpg
#   inflating: Wai Final/data_annotated/cat.2404.json
#   inflating: Wai Final/data_annotated/cat.2405.jpg
#   inflating: Wai Final/data_annotated/cat.2405.json
#   inflating: Wai Final/data_annotated/cat.2406.jpg
#   inflating: Wai Final/data_annotated/cat.2406.json
#   inflating: Wai Final/data_annotated/cat.2407.jpg
#   inflating: Wai Final/data_annotated/cat.2407.json
#   inflating: Wai Final/data_annotated/cat.2408.jpg
#   inflating: Wai Final/data_annotated/cat.2408.json
#   inflating: Wai Final/data_annotated/cat.2409.jpg
#   inflating: Wai Final/data_annotated/cat.2409.json
#   inflating: Wai Final/data_annotated/cat.2410.jpg
#   inflating: Wai Final/data_annotated/cat.2410.json
#   inflating: Wai Final/data_annotated/cat.2411.jpg
#   inflating: Wai Final/data_annotated/cat.2411.json
#   inflating: Wai Final/data_annotated/cat.2412.jpg
#   inflating: Wai Final/data_annotated/cat.2412.json
#   inflating: Wai Final/data_annotated/cat.2413.jpg
#   inflating: Wai Final/data_annotated/cat.2413.json
#   inflating: Wai Final/data_annotated/cat.2414.jpg
#   inflating: Wai Final/data_annotated/cat.2414.json
#   inflating: Wai Final/data_annotated/cat.2415.jpg
#   inflating: Wai Final/data_annotated/cat.2415.json
#   inflating: Wai Final/data_annotated/cat.2416.jpg
#   inflating: Wai Final/data_annotated/cat.2416.json
#   inflating: Wai Final/data_annotated/cat.2417.jpg
#   inflating: Wai Final/data_annotated/cat.2417.json
#   inflating: Wai Final/data_annotated/cat.2418.jpg
#   inflating: Wai Final/data_annotated/cat.2418.json
#   inflating: Wai Final/data_annotated/cat.2419.jpg
#   inflating: Wai Final/data_annotated/cat.2419.json
#   inflating: Wai Final/data_annotated/cat.2420.jpg
#   inflating: Wai Final/data_annotated/cat.2420.json
#   inflating: Wai Final/data_annotated/cat.2421.jpg
#   inflating: Wai Final/data_annotated/cat.2421.json
#   inflating: Wai Final/data_annotated/cat.2422.jpg
#   inflating: Wai Final/data_annotated/cat.2422.json
#   inflating: Wai Final/data_annotated/cat.2423.jpg
#   inflating: Wai Final/data_annotated/cat.2423.json
#   inflating: Wai Final/data_annotated/cat.2424.jpg
#   inflating: Wai Final/data_annotated/cat.2424.json
#   inflating: Wai Final/data_annotated/cat.2425.jpg
#   inflating: Wai Final/data_annotated/cat.2425.json
#   inflating: Wai Final/data_annotated/cat.2426.jpg
#   inflating: Wai Final/data_annotated/cat.2426.json
#   inflating: Wai Final/data_annotated/cat.2427.jpg
#   inflating: Wai Final/data_annotated/cat.2427.json
#   inflating: Wai Final/data_annotated/cat.2428.jpg
#   inflating: Wai Final/data_annotated/cat.2428.json
#   inflating: Wai Final/data_annotated/cat.2429.jpg
#   inflating: Wai Final/data_annotated/cat.2429.json
#   inflating: Wai Final/data_annotated/cat.2430.jpg
#   inflating: Wai Final/data_annotated/cat.2430.json
#   inflating: Wai Final/data_annotated/cat.2431.jpg
#   inflating: Wai Final/data_annotated/cat.2431.json
#   inflating: Wai Final/data_annotated/cat.2432.jpg
#   inflating: Wai Final/data_annotated/cat.2432.json
#   inflating: Wai Final/data_annotated/cat.2433.jpg
#   inflating: Wai Final/data_annotated/cat.2433.json
#   inflating: Wai Final/data_annotated/cat.2434.jpg
#   inflating: Wai Final/data_annotated/cat.2434.json
#   inflating: Wai Final/data_annotated/cat.2435.jpg
#   inflating: Wai Final/data_annotated/cat.2435.json
#   inflating: Wai Final/data_annotated/cat.2436.jpg
#   inflating: Wai Final/data_annotated/cat.2436.json
#   inflating: Wai Final/data_annotated/cat.2437.jpg
#   inflating: Wai Final/data_annotated/cat.2437.json
#   inflating: Wai Final/data_annotated/cat.2438.jpg
#   inflating: Wai Final/data_annotated/cat.2438.json
#   inflating: Wai Final/data_annotated/cat.2439.jpg
#   inflating: Wai Final/data_annotated/cat.2439.json
#   inflating: Wai Final/data_annotated/cat.2440.jpg
#   inflating: Wai Final/data_annotated/cat.2440.json
#   inflating: Wai Final/data_annotated/cat.2441.jpg
#   inflating: Wai Final/data_annotated/cat.2441.json
#   inflating: Wai Final/data_annotated/cat.2442.jpg
#   inflating: Wai Final/data_annotated/cat.2442.json
#   inflating: Wai Final/data_annotated/cat.2443.jpg
#   inflating: Wai Final/data_annotated/cat.2443.json
#   inflating: Wai Final/data_annotated/cat.2444.jpg
#   inflating: Wai Final/data_annotated/cat.2444.json
#   inflating: Wai Final/data_annotated/cat.2445.jpg
#   inflating: Wai Final/data_annotated/cat.2445.json
#   inflating: Wai Final/data_annotated/cat.2446.jpg
#   inflating: Wai Final/data_annotated/cat.2446.json
#   inflating: Wai Final/data_annotated/cat.2447.jpg
#   inflating: Wai Final/data_annotated/cat.2447.json
#   inflating: Wai Final/data_annotated/cat.2448.jpg
#   inflating: Wai Final/data_annotated/cat.2448.json
#   inflating: Wai Final/data_annotated/cat.2449.jpg
#   inflating: Wai Final/data_annotated/cat.2449.json
#   inflating: Wai Final/data_annotated/cat.2450.jpg
#   inflating: Wai Final/data_annotated/cat.2450.json
#   inflating: Wai Final/data_annotated/cat.2451.jpg
#   inflating: Wai Final/data_annotated/cat.2451.json
#   inflating: Wai Final/data_annotated/cat.2452.jpg
#   inflating: Wai Final/data_annotated/cat.2452.json
#   inflating: Wai Final/data_annotated/cat.2453.jpg
#   inflating: Wai Final/data_annotated/cat.2453.json
#   inflating: Wai Final/data_annotated/cat.2454.jpg
#   inflating: Wai Final/data_annotated/cat.2454.json
#   inflating: Wai Final/data_annotated/cat.2455.jpg
#   inflating: Wai Final/data_annotated/cat.2455.json
#   inflating: Wai Final/data_annotated/cat.2456.jpg
#   inflating: Wai Final/data_annotated/cat.2456.json
#   inflating: Wai Final/data_annotated/cat.2457.jpg
#   inflating: Wai Final/data_annotated/cat.2457.json
#   inflating: Wai Final/data_annotated/cat.2458.jpg
#   inflating: Wai Final/data_annotated/cat.2458.json
#   inflating: Wai Final/data_annotated/cat.2459.jpg
#   inflating: Wai Final/data_annotated/cat.2459.json
#   inflating: Wai Final/data_annotated/cat.2460.jpg
#   inflating: Wai Final/data_annotated/cat.2460.json
#   inflating: Wai Final/data_annotated/cat.2461.jpg
#   inflating: Wai Final/data_annotated/cat.2461.json
#   inflating: Wai Final/data_annotated/cat.2462.jpg
#   inflating: Wai Final/data_annotated/cat.2462.json
#   inflating: Wai Final/data_annotated/cat.2463.jpg
#   inflating: Wai Final/data_annotated/cat.2463.json
#   inflating: Wai Final/data_annotated/cat.2464.jpg
#   inflating: Wai Final/data_annotated/cat.2464.json
#   inflating: Wai Final/data_annotated/cat.2465.jpg
#   inflating: Wai Final/data_annotated/cat.2465.json
#   inflating: Wai Final/data_annotated/dog.2360.jpg
#   inflating: Wai Final/data_annotated/dog.2360.json
#   inflating: Wai Final/data_annotated/dog.2361.jpg
#   inflating: Wai Final/data_annotated/dog.2361.json
#   inflating: Wai Final/data_annotated/dog.2362.jpg
#   inflating: Wai Final/data_annotated/dog.2362.json
#   inflating: Wai Final/data_annotated/dog.2363.jpg
#   inflating: Wai Final/data_annotated/dog.2363.json
#   inflating: Wai Final/data_annotated/dog.2364.jpg
#   inflating: Wai Final/data_annotated/dog.2364.json
#   inflating: Wai Final/data_annotated/dog.2365.jpg
#   inflating: Wai Final/data_annotated/dog.2365.json
#   inflating: Wai Final/data_annotated/dog.2366.jpg
#   inflating: Wai Final/data_annotated/dog.2366.json
#   inflating: Wai Final/data_annotated/dog.2367.jpg
#   inflating: Wai Final/data_annotated/dog.2367.json
#   inflating: Wai Final/data_annotated/dog.2368.jpg
#   inflating: Wai Final/data_annotated/dog.2368.json
#   inflating: Wai Final/data_annotated/dog.2369.jpg
#   inflating: Wai Final/data_annotated/dog.2369.json
#   inflating: Wai Final/data_annotated/dog.2370.jpg
#   inflating: Wai Final/data_annotated/dog.2370.json
#   inflating: Wai Final/data_annotated/dog.2371.jpg
#   inflating: Wai Final/data_annotated/dog.2371.json
#   inflating: Wai Final/data_annotated/dog.2372.jpg
#   inflating: Wai Final/data_annotated/dog.2372.json
#   inflating: Wai Final/data_annotated/dog.2373.jpg
#   inflating: Wai Final/data_annotated/dog.2373.json
#   inflating: Wai Final/data_annotated/dog.2374.jpg
#   inflating: Wai Final/data_annotated/dog.2374.json
#   inflating: Wai Final/data_annotated/dog.2375.jpg
#   inflating: Wai Final/data_annotated/dog.2375.json
#   inflating: Wai Final/data_annotated/dog.2376.jpg
#   inflating: Wai Final/data_annotated/dog.2376.json
#   inflating: Wai Final/data_annotated/dog.2377.jpg
#   inflating: Wai Final/data_annotated/dog.2377.json
#   inflating: Wai Final/data_annotated/dog.2378.jpg
#   inflating: Wai Final/data_annotated/dog.2378.json
#   inflating: Wai Final/data_annotated/dog.2379.jpg
#   inflating: Wai Final/data_annotated/dog.2379.json
#   inflating: Wai Final/data_annotated/dog.2380.jpg
#   inflating: Wai Final/data_annotated/dog.2380.json
#   inflating: Wai Final/data_annotated/dog.2381.jpg
#   inflating: Wai Final/data_annotated/dog.2381.json
#   inflating: Wai Final/data_annotated/dog.2382.jpg
#   inflating: Wai Final/data_annotated/dog.2382.json
#   inflating: Wai Final/data_annotated/dog.2383.jpg
#   inflating: Wai Final/data_annotated/dog.2383.json
#   inflating: Wai Final/data_annotated/dog.2384.jpg
#   inflating: Wai Final/data_annotated/dog.2384.json
#   inflating: Wai Final/data_annotated/dog.2385.jpg
#   inflating: Wai Final/data_annotated/dog.2385.json
#   inflating: Wai Final/data_annotated/dog.2386.jpg
#   inflating: Wai Final/data_annotated/dog.2386.json
#   inflating: Wai Final/data_annotated/dog.2387.jpg
#   inflating: Wai Final/data_annotated/dog.2387.json
#   inflating: Wai Final/data_annotated/dog.2388.jpg
#   inflating: Wai Final/data_annotated/dog.2388.json
#   inflating: Wai Final/data_annotated/dog.2389.jpg
#   inflating: Wai Final/data_annotated/dog.2389.json
#   inflating: Wai Final/data_annotated/dog.2390.jpg
#   inflating: Wai Final/data_annotated/dog.2390.json
#   inflating: Wai Final/data_annotated/dog.2391.jpg
#   inflating: Wai Final/data_annotated/dog.2391.json
#   inflating: Wai Final/data_annotated/dog.2392.jpg
#   inflating: Wai Final/data_annotated/dog.2392.json
#   inflating: Wai Final/data_annotated/dog.2393.jpg
#   inflating: Wai Final/data_annotated/dog.2393.json
#   inflating: Wai Final/data_annotated/dog.2394.jpg
#   inflating: Wai Final/data_annotated/dog.2394.json
#   inflating: Wai Final/data_annotated/dog.2395.jpg
#   inflating: Wai Final/data_annotated/dog.2395.json
#   inflating: Wai Final/data_annotated/dog.2396.jpg
#   inflating: Wai Final/data_annotated/dog.2396.json
#   inflating: Wai Final/data_annotated/dog.2397.jpg
#   inflating: Wai Final/data_annotated/dog.2397.json
#   inflating: Wai Final/data_annotated/dog.2398.jpg
#   inflating: Wai Final/data_annotated/dog.2398.json
#   inflating: Wai Final/data_annotated/dog.2399.jpg
#   inflating: Wai Final/data_annotated/dog.2399.json
#   inflating: Wai Final/data_annotated/dog.2400.jpg
#   inflating: Wai Final/data_annotated/dog.2400.json
#   inflating: Wai Final/data_annotated/dog.2401.jpg
#   inflating: Wai Final/data_annotated/dog.2401.json
#   inflating: Wai Final/data_annotated/dog.2402.jpg
#   inflating: Wai Final/data_annotated/dog.2402.json
#   inflating: Wai Final/data_annotated/dog.2403.jpg
#   inflating: Wai Final/data_annotated/dog.2403.json
#   inflating: Wai Final/data_annotated/dog.2404.jpg
#   inflating: Wai Final/data_annotated/dog.2404.json
#   inflating: Wai Final/data_annotated/dog.2405.jpg
#   inflating: Wai Final/data_annotated/dog.2405.json
#   inflating: Wai Final/data_annotated/dog.2406.jpg
#   inflating: Wai Final/data_annotated/dog.2406.json
#   inflating: Wai Final/data_annotated/dog.2407.jpg
#   inflating: Wai Final/data_annotated/dog.2407.json
#   inflating: Wai Final/data_annotated/dog.2408.jpg
#   inflating: Wai Final/data_annotated/dog.2408.json
#   inflating: Wai Final/data_annotated/dog.2409.jpg
#   inflating: Wai Final/data_annotated/dog.2409.json
#   inflating: Wai Final/data_annotated/dog.2410.jpg
#   inflating: Wai Final/data_annotated/dog.2410.json
#   inflating: Wai Final/data_annotated/dog.2411.jpg
#   inflating: Wai Final/data_annotated/dog.2411.json
#   inflating: Wai Final/data_annotated/dog.2412.jpg
#   inflating: Wai Final/data_annotated/dog.2412.json
#   inflating: Wai Final/data_annotated/dog.2413.jpg
#   inflating: Wai Final/data_annotated/dog.2413.json
#   inflating: Wai Final/data_annotated/dog.2414.jpg
#   inflating: Wai Final/data_annotated/dog.2414.json
#   inflating: Wai Final/data_annotated/dog.2415.jpg
#   inflating: Wai Final/data_annotated/dog.2415.json
#   inflating: Wai Final/data_annotated/dog.2416.jpg
#   inflating: Wai Final/data_annotated/dog.2416.json
#   inflating: Wai Final/data_annotated/dog.2417.jpg
#   inflating: Wai Final/data_annotated/dog.2417.json
#   inflating: Wai Final/data_annotated/dog.2418.jpg
#   inflating: Wai Final/data_annotated/dog.2418.json
#   inflating: Wai Final/data_annotated/dog.2419.jpg
#   inflating: Wai Final/data_annotated/dog.2419.json
#   inflating: Wai Final/data_annotated/dog.2420.jpg
#   inflating: Wai Final/data_annotated/dog.2420.json
#   inflating: Wai Final/data_annotated/dog.2421.jpg
#   inflating: Wai Final/data_annotated/dog.2421.json
#   inflating: Wai Final/data_annotated/dog.2422.jpg
#   inflating: Wai Final/data_annotated/dog.2422.json
#   inflating: Wai Final/data_annotated/dog.2423.jpg
#   inflating: Wai Final/data_annotated/dog.2423.json
#   inflating: Wai Final/data_annotated/dog.2424.jpg
#   inflating: Wai Final/data_annotated/dog.2424.json
#   inflating: Wai Final/data_annotated/dog.2425.jpg
#   inflating: Wai Final/data_annotated/dog.2425.json
#   inflating: Wai Final/data_annotated/dog.2426.jpg
#   inflating: Wai Final/data_annotated/dog.2426.json
#   inflating: Wai Final/data_annotated/dog.2427.jpg
#   inflating: Wai Final/data_annotated/dog.2427.json
#   inflating: Wai Final/data_annotated/dog.2428.jpg
#   inflating: Wai Final/data_annotated/dog.2428.json
#   inflating: Wai Final/data_annotated/dog.2429.jpg
#   inflating: Wai Final/data_annotated/dog.2429.json
#   inflating: Wai Final/data_annotated/dog.2430.jpg
#   inflating: Wai Final/data_annotated/dog.2430.json
#   inflating: Wai Final/data_annotated/dog.2431.jpg
#   inflating: Wai Final/data_annotated/dog.2431.json
#   inflating: Wai Final/data_annotated/dog.2432.jpg
#   inflating: Wai Final/data_annotated/dog.2432.json
#   inflating: Wai Final/data_annotated/dog.2433.jpg
#   inflating: Wai Final/data_annotated/dog.2433.json
#   inflating: Wai Final/data_annotated/dog.2434.jpg
#   inflating: Wai Final/data_annotated/dog.2434.json
#   inflating: Wai Final/data_annotated/dog.2435.jpg
#   inflating: Wai Final/data_annotated/dog.2435.json
#   inflating: Wai Final/data_annotated/dog.2436.jpg
#   inflating: Wai Final/data_annotated/dog.2436.json
#   inflating: Wai Final/data_annotated/dog.2437.jpg
#   inflating: Wai Final/data_annotated/dog.2437.json
#   inflating: Wai Final/data_annotated/dog.2438.jpg
#   inflating: Wai Final/data_annotated/dog.2438.json
#   inflating: Wai Final/data_annotated/dog.2439.jpg
#   inflating: Wai Final/data_annotated/dog.2439.json
#   inflating: Wai Final/data_annotated/dog.2440.jpg
#   inflating: Wai Final/data_annotated/dog.2440.json
#   inflating: Wai Final/data_annotated/dog.2441.jpg
#   inflating: Wai Final/data_annotated/dog.2441.json
#   inflating: Wai Final/data_annotated/dog.2442.jpg
#   inflating: Wai Final/data_annotated/dog.2442.json
#   inflating: Wai Final/data_annotated/dog.2443.jpg
#   inflating: Wai Final/data_annotated/dog.2443.json
#   inflating: Wai Final/data_annotated/dog.2444.jpg
#   inflating: Wai Final/data_annotated/dog.2444.json
#   inflating: Wai Final/data_annotated/dog.2445.jpg
#   inflating: Wai Final/data_annotated/dog.2445.json
#   inflating: Wai Final/data_annotated/dog.2446.jpg
#   inflating: Wai Final/data_annotated/dog.2446.json
#   inflating: Wai Final/data_annotated/dog.2447.jpg
#   inflating: Wai Final/data_annotated/dog.2447.json
#   inflating: Wai Final/data_annotated/dog.2448.jpg
#   inflating: Wai Final/data_annotated/dog.2448.json
#   inflating: Wai Final/data_annotated/dog.2449.jpg
#   inflating: Wai Final/data_annotated/dog.2449.json
#   inflating: Wai Final/data_annotated/dog.2450.jpg
#   inflating: Wai Final/data_annotated/dog.2450.json
#   inflating: Wai Final/data_annotated/dog.2451.jpg
#   inflating: Wai Final/data_annotated/dog.2451.json
#   inflating: Wai Final/data_annotated/dog.2452.jpg
#   inflating: Wai Final/data_annotated/dog.2452.json
#   inflating: Wai Final/data_annotated/dog.2453.jpg
#   inflating: Wai Final/data_annotated/dog.2453.json
#   inflating: Wai Final/data_annotated/dog.2454.jpg
#   inflating: Wai Final/data_annotated/dog.2454.json
#   inflating: Wai Final/data_annotated/dog.2455.jpg
#   inflating: Wai Final/data_annotated/dog.2455.json
#   inflating: Wai Final/data_annotated/dog.2456.jpg
#   inflating: Wai Final/data_annotated/dog.2456.json
#   inflating: Wai Final/data_annotated/dog.2457.jpg
#   inflating: Wai Final/data_annotated/dog.2457.json
#   inflating: Wai Final/data_annotated/dog.2458.jpg
#   inflating: Wai Final/data_annotated/dog.2458.json
#   inflating: Wai Final/data_annotated/dog.2459.jpg
#   inflating: Wai Final/data_annotated/dog.2459.json
#   inflating: Wai Final/data_annotated/labels.txt
#    creating: Wai Final/encoded_masks/
#   inflating: Wai Final/encoded_masks/cat.2366.png
#   inflating: Wai Final/encoded_masks/cat.2367.png
#   inflating: Wai Final/encoded_masks/cat.2368.png
#   inflating: Wai Final/encoded_masks/cat.2369.png
#   inflating: Wai Final/encoded_masks/cat.2370.png
#   inflating: Wai Final/encoded_masks/cat.2371.png
#   inflating: Wai Final/encoded_masks/cat.2372.png
#   inflating: Wai Final/encoded_masks/cat.2373.png
#   inflating: Wai Final/encoded_masks/cat.2374.png
#   inflating: Wai Final/encoded_masks/cat.2375.png
#   inflating: Wai Final/encoded_masks/cat.2376.png
#   inflating: Wai Final/encoded_masks/cat.2377.png
#   inflating: Wai Final/encoded_masks/cat.2378.png
#   inflating: Wai Final/encoded_masks/cat.2379.png
#   inflating: Wai Final/encoded_masks/cat.2380.png
#   inflating: Wai Final/encoded_masks/cat.2381.png
#   inflating: Wai Final/encoded_masks/cat.2382.png
#   inflating: Wai Final/encoded_masks/cat.2383.png
#   inflating: Wai Final/encoded_masks/cat.2384.png
#   inflating: Wai Final/encoded_masks/cat.2385.png
#   inflating: Wai Final/encoded_masks/cat.2386.png
#   inflating: Wai Final/encoded_masks/cat.2387.png
#   inflating: Wai Final/encoded_masks/cat.2388.png
#   inflating: Wai Final/encoded_masks/cat.2389.png
#   inflating: Wai Final/encoded_masks/cat.2390.png
#   inflating: Wai Final/encoded_masks/cat.2391.png
#   inflating: Wai Final/encoded_masks/cat.2392.png
#   inflating: Wai Final/encoded_masks/cat.2393.png
#   inflating: Wai Final/encoded_masks/cat.2394.png
#   inflating: Wai Final/encoded_masks/cat.2395.png
#   inflating: Wai Final/encoded_masks/cat.2396.png
#   inflating: Wai Final/encoded_masks/cat.2397.png
#   inflating: Wai Final/encoded_masks/cat.2398.png
#   inflating: Wai Final/encoded_masks/cat.2399.png
#   inflating: Wai Final/encoded_masks/cat.2400.png
#   inflating: Wai Final/encoded_masks/cat.2401.png
#   inflating: Wai Final/encoded_masks/cat.2402.png
#   inflating: Wai Final/encoded_masks/cat.2403.png
#   inflating: Wai Final/encoded_masks/cat.2404.png
#   inflating: Wai Final/encoded_masks/cat.2405.png
#   inflating: Wai Final/encoded_masks/cat.2406.png
#   inflating: Wai Final/encoded_masks/cat.2407.png
#   inflating: Wai Final/encoded_masks/cat.2408.png
#   inflating: Wai Final/encoded_masks/cat.2409.png
#   inflating: Wai Final/encoded_masks/cat.2410.png
#   inflating: Wai Final/encoded_masks/cat.2411.png
#   inflating: Wai Final/encoded_masks/cat.2412.png
#   inflating: Wai Final/encoded_masks/cat.2413.png
#   inflating: Wai Final/encoded_masks/cat.2414.png
#   inflating: Wai Final/encoded_masks/cat.2415.png
#   inflating: Wai Final/encoded_masks/cat.2416.png
#   inflating: Wai Final/encoded_masks/cat.2417.png
#   inflating: Wai Final/encoded_masks/cat.2418.png
#   inflating: Wai Final/encoded_masks/cat.2419.png
#   inflating: Wai Final/encoded_masks/cat.2420.png
#   inflating: Wai Final/encoded_masks/cat.2421.png
#   inflating: Wai Final/encoded_masks/cat.2422.png
#   inflating: Wai Final/encoded_masks/cat.2423.png
#   inflating: Wai Final/encoded_masks/cat.2424.png
#   inflating: Wai Final/encoded_masks/cat.2425.png
#   inflating: Wai Final/encoded_masks/cat.2426.png
#   inflating: Wai Final/encoded_masks/cat.2427.png
#   inflating: Wai Final/encoded_masks/cat.2428.png
#   inflating: Wai Final/encoded_masks/cat.2429.png
#   inflating: Wai Final/encoded_masks/cat.2430.png
#   inflating: Wai Final/encoded_masks/cat.2431.png
#   inflating: Wai Final/encoded_masks/cat.2432.png
#   inflating: Wai Final/encoded_masks/cat.2433.png
#   inflating: Wai Final/encoded_masks/cat.2434.png
#   inflating: Wai Final/encoded_masks/cat.2435.png
#   inflating: Wai Final/encoded_masks/cat.2436.png
#   inflating: Wai Final/encoded_masks/cat.2437.png
#   inflating: Wai Final/encoded_masks/cat.2438.png
#   inflating: Wai Final/encoded_masks/cat.2439.png
#   inflating: Wai Final/encoded_masks/cat.2440.png
#   inflating: Wai Final/encoded_masks/cat.2441.png
#   inflating: Wai Final/encoded_masks/cat.2442.png
#   inflating: Wai Final/encoded_masks/cat.2443.png
#   inflating: Wai Final/encoded_masks/cat.2444.png
#   inflating: Wai Final/encoded_masks/cat.2445.png
#   inflating: Wai Final/encoded_masks/cat.2446.png
#   inflating: Wai Final/encoded_masks/cat.2447.png
#   inflating: Wai Final/encoded_masks/cat.2448.png
#   inflating: Wai Final/encoded_masks/cat.2449.png
#   inflating: Wai Final/encoded_masks/cat.2450.png
#   inflating: Wai Final/encoded_masks/cat.2451.png
#   inflating: Wai Final/encoded_masks/cat.2452.png
#   inflating: Wai Final/encoded_masks/cat.2453.png
#   inflating: Wai Final/encoded_masks/cat.2454.png
#   inflating: Wai Final/encoded_masks/cat.2455.png
#   inflating: Wai Final/encoded_masks/cat.2456.png
#   inflating: Wai Final/encoded_masks/cat.2457.png
#   inflating: Wai Final/encoded_masks/cat.2458.png
#   inflating: Wai Final/encoded_masks/cat.2459.png
#   inflating: Wai Final/encoded_masks/cat.2460.png
#   inflating: Wai Final/encoded_masks/cat.2461.png
#   inflating: Wai Final/encoded_masks/cat.2462.png
#   inflating: Wai Final/encoded_masks/cat.2463.png
#   inflating: Wai Final/encoded_masks/cat.2464.png
#   inflating: Wai Final/encoded_masks/cat.2465.png
#   inflating: Wai Final/encoded_masks/dog.2360.png
#   inflating: Wai Final/encoded_masks/dog.2361.png
#   inflating: Wai Final/encoded_masks/dog.2362.png
#   inflating: Wai Final/encoded_masks/dog.2363.png
#   inflating: Wai Final/encoded_masks/dog.2364.png
#   inflating: Wai Final/encoded_masks/dog.2365.png
#   inflating: Wai Final/encoded_masks/dog.2366.png
#   inflating: Wai Final/encoded_masks/dog.2367.png
#   inflating: Wai Final/encoded_masks/dog.2368.png
#   inflating: Wai Final/encoded_masks/dog.2369.png
#   inflating: Wai Final/encoded_masks/dog.2370.png
#   inflating: Wai Final/encoded_masks/dog.2371.png
#   inflating: Wai Final/encoded_masks/dog.2372.png
#   inflating: Wai Final/encoded_masks/dog.2373.png
#   inflating: Wai Final/encoded_masks/dog.2374.png
#   inflating: Wai Final/encoded_masks/dog.2375.png
#   inflating: Wai Final/encoded_masks/dog.2376.png
#   inflating: Wai Final/encoded_masks/dog.2377.png
#   inflating: Wai Final/encoded_masks/dog.2378.png
#   inflating: Wai Final/encoded_masks/dog.2379.png
#   inflating: Wai Final/encoded_masks/dog.2380.png
#   inflating: Wai Final/encoded_masks/dog.2381.png
#   inflating: Wai Final/encoded_masks/dog.2382.png
#   inflating: Wai Final/encoded_masks/dog.2383.png
#   inflating: Wai Final/encoded_masks/dog.2384.png
#   inflating: Wai Final/encoded_masks/dog.2385.png
#   inflating: Wai Final/encoded_masks/dog.2386.png
#   inflating: Wai Final/encoded_masks/dog.2387.png
#   inflating: Wai Final/encoded_masks/dog.2388.png
#   inflating: Wai Final/encoded_masks/dog.2389.png
#   inflating: Wai Final/encoded_masks/dog.2390.png
#   inflating: Wai Final/encoded_masks/dog.2391.png
#   inflating: Wai Final/encoded_masks/dog.2392.png
#   inflating: Wai Final/encoded_masks/dog.2393.png
#   inflating: Wai Final/encoded_masks/dog.2394.png
#   inflating: Wai Final/encoded_masks/dog.2395.png
#   inflating: Wai Final/encoded_masks/dog.2396.png
#   inflating: Wai Final/encoded_masks/dog.2397.png
#   inflating: Wai Final/encoded_masks/dog.2398.png
#   inflating: Wai Final/encoded_masks/dog.2399.png
#   inflating: Wai Final/encoded_masks/dog.2400.png
#   inflating: Wai Final/encoded_masks/dog.2401.png
#   inflating: Wai Final/encoded_masks/dog.2402.png
#   inflating: Wai Final/encoded_masks/dog.2403.png
#   inflating: Wai Final/encoded_masks/dog.2404.png
#   inflating: Wai Final/encoded_masks/dog.2405.png
#   inflating: Wai Final/encoded_masks/dog.2406.png
#   inflating: Wai Final/encoded_masks/dog.2407.png
#   inflating: Wai Final/encoded_masks/dog.2408.png
#   inflating: Wai Final/encoded_masks/dog.2409.png
#   inflating: Wai Final/encoded_masks/dog.2410.png
#   inflating: Wai Final/encoded_masks/dog.2411.png
#   inflating: Wai Final/encoded_masks/dog.2412.png
#   inflating: Wai Final/encoded_masks/dog.2413.png
#   inflating: Wai Final/encoded_masks/dog.2414.png
#   inflating: Wai Final/encoded_masks/dog.2415.png
#   inflating: Wai Final/encoded_masks/dog.2416.png
#   inflating: Wai Final/encoded_masks/dog.2417.png
#   inflating: Wai Final/encoded_masks/dog.2418.png
#   inflating: Wai Final/encoded_masks/dog.2419.png
#   inflating: Wai Final/encoded_masks/dog.2420.png
#   inflating: Wai Final/encoded_masks/dog.2421.png
#   inflating: Wai Final/encoded_masks/dog.2422.png
#   inflating: Wai Final/encoded_masks/dog.2423.png
#   inflating: Wai Final/encoded_masks/dog.2424.png
#   inflating: Wai Final/encoded_masks/dog.2425.png
#   inflating: Wai Final/encoded_masks/dog.2426.png
#   inflating: Wai Final/encoded_masks/dog.2427.png
#   inflating: Wai Final/encoded_masks/dog.2428.png
#   inflating: Wai Final/encoded_masks/dog.2429.png
#   inflating: Wai Final/encoded_masks/dog.2430.png
#   inflating: Wai Final/encoded_masks/dog.2431.png
#   inflating: Wai Final/encoded_masks/dog.2432.png
#   inflating: Wai Final/encoded_masks/dog.2433.png
#   inflating: Wai Final/encoded_masks/dog.2434.png
#   inflating: Wai Final/encoded_masks/dog.2435.png
#   inflating: Wai Final/encoded_masks/dog.2436.png
#   inflating: Wai Final/encoded_masks/dog.2437.png
#   inflating: Wai Final/encoded_masks/dog.2438.png
#   inflating: Wai Final/encoded_masks/dog.2439.png
#   inflating: Wai Final/encoded_masks/dog.2440.png
#   inflating: Wai Final/encoded_masks/dog.2441.png
#   inflating: Wai Final/encoded_masks/dog.2442.png
#   inflating: Wai Final/encoded_masks/dog.2443.png
#   inflating: Wai Final/encoded_masks/dog.2444.png
#   inflating: Wai Final/encoded_masks/dog.2445.png
#   inflating: Wai Final/encoded_masks/dog.2446.png
#   inflating: Wai Final/encoded_masks/dog.2447.png
#   inflating: Wai Final/encoded_masks/dog.2448.png
#   inflating: Wai Final/encoded_masks/dog.2449.png
#   inflating: Wai Final/encoded_masks/dog.2450.png
#   inflating: Wai Final/encoded_masks/dog.2451.png
#   inflating: Wai Final/encoded_masks/dog.2452.png
#   inflating: Wai Final/encoded_masks/dog.2453.png
#   inflating: Wai Final/encoded_masks/dog.2454.png
#   inflating: Wai Final/encoded_masks/dog.2455.png
#   inflating: Wai Final/encoded_masks/dog.2456.png
#   inflating: Wai Final/encoded_masks/dog.2457.png
#   inflating: Wai Final/encoded_masks/dog.2458.png
#   inflating: Wai Final/encoded_masks/dog.2459.png
#    creating: Wai Final/JPEGImages/
#   inflating: Wai Final/JPEGImages/cat.2366.jpg
#   inflating: Wai Final/JPEGImages/cat.2367.jpg
#   inflating: Wai Final/JPEGImages/cat.2368.jpg
#   inflating: Wai Final/JPEGImages/cat.2369.jpg
#   inflating: Wai Final/JPEGImages/cat.2370.jpg
#   inflating: Wai Final/JPEGImages/cat.2371.jpg
#   inflating: Wai Final/JPEGImages/cat.2372.jpg
#   inflating: Wai Final/JPEGImages/cat.2373.jpg
#   inflating: Wai Final/JPEGImages/cat.2374.jpg
#   inflating: Wai Final/JPEGImages/cat.2375.jpg
#   inflating: Wai Final/JPEGImages/cat.2376.jpg
#   inflating: Wai Final/JPEGImages/cat.2377.jpg
#   inflating: Wai Final/JPEGImages/cat.2378.jpg
#   inflating: Wai Final/JPEGImages/cat.2379.jpg
#   inflating: Wai Final/JPEGImages/cat.2380.jpg
#   inflating: Wai Final/JPEGImages/cat.2381.jpg
#   inflating: Wai Final/JPEGImages/cat.2382.jpg
#   inflating: Wai Final/JPEGImages/cat.2383.jpg
#   inflating: Wai Final/JPEGImages/cat.2384.jpg
#   inflating: Wai Final/JPEGImages/cat.2385.jpg
#   inflating: Wai Final/JPEGImages/cat.2386.jpg
#   inflating: Wai Final/JPEGImages/cat.2387.jpg
#   inflating: Wai Final/JPEGImages/cat.2388.jpg
#   inflating: Wai Final/JPEGImages/cat.2389.jpg
#   inflating: Wai Final/JPEGImages/cat.2390.jpg
#   inflating: Wai Final/JPEGImages/cat.2391.jpg
#   inflating: Wai Final/JPEGImages/cat.2392.jpg
#   inflating: Wai Final/JPEGImages/cat.2393.jpg
#   inflating: Wai Final/JPEGImages/cat.2394.jpg
#   inflating: Wai Final/JPEGImages/cat.2395.jpg
#   inflating: Wai Final/JPEGImages/cat.2396.jpg
#   inflating: Wai Final/JPEGImages/cat.2397.jpg
#   inflating: Wai Final/JPEGImages/cat.2398.jpg
#   inflating: Wai Final/JPEGImages/cat.2399.jpg
#   inflating: Wai Final/JPEGImages/cat.2400.jpg
#   inflating: Wai Final/JPEGImages/cat.2401.jpg
#   inflating: Wai Final/JPEGImages/cat.2402.jpg
#   inflating: Wai Final/JPEGImages/cat.2403.jpg
#   inflating: Wai Final/JPEGImages/cat.2404.jpg
#   inflating: Wai Final/JPEGImages/cat.2405.jpg
#   inflating: Wai Final/JPEGImages/cat.2406.jpg
#   inflating: Wai Final/JPEGImages/cat.2407.jpg
#   inflating: Wai Final/JPEGImages/cat.2408.jpg
#   inflating: Wai Final/JPEGImages/cat.2409.jpg
#   inflating: Wai Final/JPEGImages/cat.2410.jpg
#   inflating: Wai Final/JPEGImages/cat.2411.jpg
#   inflating: Wai Final/JPEGImages/cat.2412.jpg
#   inflating: Wai Final/JPEGImages/cat.2413.jpg
#   inflating: Wai Final/JPEGImages/cat.2414.jpg
#   inflating: Wai Final/JPEGImages/cat.2415.jpg
#   inflating: Wai Final/JPEGImages/cat.2416.jpg
#   inflating: Wai Final/JPEGImages/cat.2417.jpg
#   inflating: Wai Final/JPEGImages/cat.2418.jpg
#   inflating: Wai Final/JPEGImages/cat.2419.jpg
#   inflating: Wai Final/JPEGImages/cat.2420.jpg
#   inflating: Wai Final/JPEGImages/cat.2421.jpg
#   inflating: Wai Final/JPEGImages/cat.2422.jpg
#   inflating: Wai Final/JPEGImages/cat.2423.jpg
#   inflating: Wai Final/JPEGImages/cat.2424.jpg
#   inflating: Wai Final/JPEGImages/cat.2425.jpg
#   inflating: Wai Final/JPEGImages/cat.2426.jpg
#   inflating: Wai Final/JPEGImages/cat.2427.jpg
#   inflating: Wai Final/JPEGImages/cat.2428.jpg
#   inflating: Wai Final/JPEGImages/cat.2429.jpg
#   inflating: Wai Final/JPEGImages/cat.2430.jpg
#   inflating: Wai Final/JPEGImages/cat.2431.jpg
#   inflating: Wai Final/JPEGImages/cat.2432.jpg
#   inflating: Wai Final/JPEGImages/cat.2433.jpg
#   inflating: Wai Final/JPEGImages/cat.2434.jpg
#   inflating: Wai Final/JPEGImages/cat.2435.jpg
#   inflating: Wai Final/JPEGImages/cat.2436.jpg
#   inflating: Wai Final/JPEGImages/cat.2437.jpg
#   inflating: Wai Final/JPEGImages/cat.2438.jpg
#   inflating: Wai Final/JPEGImages/cat.2439.jpg
#   inflating: Wai Final/JPEGImages/cat.2440.jpg
#   inflating: Wai Final/JPEGImages/cat.2441.jpg
#   inflating: Wai Final/JPEGImages/cat.2442.jpg
#   inflating: Wai Final/JPEGImages/cat.2443.jpg
#   inflating: Wai Final/JPEGImages/cat.2444.jpg
#   inflating: Wai Final/JPEGImages/cat.2445.jpg
#   inflating: Wai Final/JPEGImages/cat.2446.jpg
#   inflating: Wai Final/JPEGImages/cat.2447.jpg
#   inflating: Wai Final/JPEGImages/cat.2448.jpg
#   inflating: Wai Final/JPEGImages/cat.2449.jpg
#   inflating: Wai Final/JPEGImages/cat.2450.jpg
#   inflating: Wai Final/JPEGImages/cat.2451.jpg
#   inflating: Wai Final/JPEGImages/cat.2452.jpg
#   inflating: Wai Final/JPEGImages/cat.2453.jpg
#   inflating: Wai Final/JPEGImages/cat.2454.jpg
#   inflating: Wai Final/JPEGImages/cat.2455.jpg
#   inflating: Wai Final/JPEGImages/cat.2456.jpg
#   inflating: Wai Final/JPEGImages/cat.2457.jpg
#   inflating: Wai Final/JPEGImages/cat.2458.jpg
#   inflating: Wai Final/JPEGImages/cat.2459.jpg
#   inflating: Wai Final/JPEGImages/cat.2460.jpg
#   inflating: Wai Final/JPEGImages/cat.2461.jpg
#   inflating: Wai Final/JPEGImages/cat.2462.jpg
#   inflating: Wai Final/JPEGImages/cat.2463.jpg
#   inflating: Wai Final/JPEGImages/cat.2464.jpg
#   inflating: Wai Final/JPEGImages/cat.2465.jpg
#   inflating: Wai Final/JPEGImages/dog.2360.jpg
#   inflating: Wai Final/JPEGImages/dog.2361.jpg
#   inflating: Wai Final/JPEGImages/dog.2362.jpg
#   inflating: Wai Final/JPEGImages/dog.2363.jpg
#   inflating: Wai Final/JPEGImages/dog.2364.jpg
#   inflating: Wai Final/JPEGImages/dog.2365.jpg
#   inflating: Wai Final/JPEGImages/dog.2366.jpg
#   inflating: Wai Final/JPEGImages/dog.2367.jpg
#   inflating: Wai Final/JPEGImages/dog.2368.jpg
#   inflating: Wai Final/JPEGImages/dog.2369.jpg
#   inflating: Wai Final/JPEGImages/dog.2370.jpg
#   inflating: Wai Final/JPEGImages/dog.2371.jpg
#   inflating: Wai Final/JPEGImages/dog.2372.jpg
#   inflating: Wai Final/JPEGImages/dog.2373.jpg
#   inflating: Wai Final/JPEGImages/dog.2374.jpg
#   inflating: Wai Final/JPEGImages/dog.2375.jpg
#   inflating: Wai Final/JPEGImages/dog.2376.jpg
#   inflating: Wai Final/JPEGImages/dog.2377.jpg
#   inflating: Wai Final/JPEGImages/dog.2378.jpg
#   inflating: Wai Final/JPEGImages/dog.2379.jpg
#   inflating: Wai Final/JPEGImages/dog.2380.jpg
#   inflating: Wai Final/JPEGImages/dog.2381.jpg
#   inflating: Wai Final/JPEGImages/dog.2382.jpg
#   inflating: Wai Final/JPEGImages/dog.2383.jpg
#   inflating: Wai Final/JPEGImages/dog.2384.jpg
#   inflating: Wai Final/JPEGImages/dog.2385.jpg
#   inflating: Wai Final/JPEGImages/dog.2386.jpg
#   inflating: Wai Final/JPEGImages/dog.2387.jpg
#   inflating: Wai Final/JPEGImages/dog.2388.jpg
#   inflating: Wai Final/JPEGImages/dog.2389.jpg
#   inflating: Wai Final/JPEGImages/dog.2390.jpg
#   inflating: Wai Final/JPEGImages/dog.2391.jpg
#   inflating: Wai Final/JPEGImages/dog.2392.jpg
#   inflating: Wai Final/JPEGImages/dog.2393.jpg
#   inflating: Wai Final/JPEGImages/dog.2394.jpg
#   inflating: Wai Final/JPEGImages/dog.2395.jpg
#   inflating: Wai Final/JPEGImages/dog.2396.jpg
#   inflating: Wai Final/JPEGImages/dog.2397.jpg
#   inflating: Wai Final/JPEGImages/dog.2398.jpg
#   inflating: Wai Final/JPEGImages/dog.2399.jpg
#   inflating: Wai Final/JPEGImages/dog.2400.jpg
#   inflating: Wai Final/JPEGImages/dog.2401.jpg
#   inflating: Wai Final/JPEGImages/dog.2402.jpg
#   inflating: Wai Final/JPEGImages/dog.2403.jpg
#   inflating: Wai Final/JPEGImages/dog.2404.jpg
#   inflating: Wai Final/JPEGImages/dog.2405.jpg
#   inflating: Wai Final/JPEGImages/dog.2406.jpg
#   inflating: Wai Final/JPEGImages/dog.2407.jpg
#   inflating: Wai Final/JPEGImages/dog.2408.jpg
#   inflating: Wai Final/JPEGImages/dog.2409.jpg
#   inflating: Wai Final/JPEGImages/dog.2410.jpg
#   inflating: Wai Final/JPEGImages/dog.2411.jpg
#   inflating: Wai Final/JPEGImages/dog.2412.jpg
#   inflating: Wai Final/JPEGImages/dog.2413.jpg
#   inflating: Wai Final/JPEGImages/dog.2414.jpg
#   inflating: Wai Final/JPEGImages/dog.2415.jpg
#   inflating: Wai Final/JPEGImages/dog.2416.jpg
#   inflating: Wai Final/JPEGImages/dog.2417.jpg
#   inflating: Wai Final/JPEGImages/dog.2418.jpg
#   inflating: Wai Final/JPEGImages/dog.2419.jpg
#   inflating: Wai Final/JPEGImages/dog.2420.jpg
#   inflating: Wai Final/JPEGImages/dog.2421.jpg
#   inflating: Wai Final/JPEGImages/dog.2422.jpg
#   inflating: Wai Final/JPEGImages/dog.2423.jpg
#   inflating: Wai Final/JPEGImages/dog.2424.jpg
#   inflating: Wai Final/JPEGImages/dog.2425.jpg
#   inflating: Wai Final/JPEGImages/dog.2426.jpg
#   inflating: Wai Final/JPEGImages/dog.2427.jpg
#   inflating: Wai Final/JPEGImages/dog.2428.jpg
#   inflating: Wai Final/JPEGImages/dog.2429.jpg
#   inflating: Wai Final/JPEGImages/dog.2430.jpg
#   inflating: Wai Final/JPEGImages/dog.2431.jpg
#   inflating: Wai Final/JPEGImages/dog.2432.jpg
#   inflating: Wai Final/JPEGImages/dog.2433.jpg
#   inflating: Wai Final/JPEGImages/dog.2434.jpg
#   inflating: Wai Final/JPEGImages/dog.2435.jpg
#   inflating: Wai Final/JPEGImages/dog.2436.jpg
#   inflating: Wai Final/JPEGImages/dog.2437.jpg
#   inflating: Wai Final/JPEGImages/dog.2438.jpg
#   inflating: Wai Final/JPEGImages/dog.2439.jpg
#   inflating: Wai Final/JPEGImages/dog.2440.jpg
#   inflating: Wai Final/JPEGImages/dog.2441.jpg
#   inflating: Wai Final/JPEGImages/dog.2442.jpg
#   inflating: Wai Final/JPEGImages/dog.2443.jpg
#   inflating: Wai Final/JPEGImages/dog.2444.jpg
#   inflating: Wai Final/JPEGImages/dog.2445.jpg
#   inflating: Wai Final/JPEGImages/dog.2446.jpg
#   inflating: Wai Final/JPEGImages/dog.2447.jpg
#   inflating: Wai Final/JPEGImages/dog.2448.jpg
#   inflating: Wai Final/JPEGImages/dog.2449.jpg
#   inflating: Wai Final/JPEGImages/dog.2450.jpg
#   inflating: Wai Final/JPEGImages/dog.2451.jpg
#   inflating: Wai Final/JPEGImages/dog.2452.jpg
#   inflating: Wai Final/JPEGImages/dog.2453.jpg
#   inflating: Wai Final/JPEGImages/dog.2454.jpg
#   inflating: Wai Final/JPEGImages/dog.2455.jpg
#   inflating: Wai Final/JPEGImages/dog.2456.jpg
#   inflating: Wai Final/JPEGImages/dog.2457.jpg
#   inflating: Wai Final/JPEGImages/dog.2458.jpg
#   inflating: Wai Final/JPEGImages/dog.2459.jpg
#    creating: Wai Final/SegmentationClass/
#   inflating: Wai Final/SegmentationClass/cat.2366.png
#   inflating: Wai Final/SegmentationClass/cat.2367.png
#   inflating: Wai Final/SegmentationClass/cat.2368.png
#   inflating: Wai Final/SegmentationClass/cat.2369.png
#   inflating: Wai Final/SegmentationClass/cat.2370.png
#   inflating: Wai Final/SegmentationClass/cat.2371.png
#   inflating: Wai Final/SegmentationClass/cat.2372.png
#   inflating: Wai Final/SegmentationClass/cat.2373.png
#   inflating: Wai Final/SegmentationClass/cat.2374.png
#   inflating: Wai Final/SegmentationClass/cat.2375.png
#   inflating: Wai Final/SegmentationClass/cat.2376.png
#   inflating: Wai Final/SegmentationClass/cat.2377.png
#   inflating: Wai Final/SegmentationClass/cat.2378.png
#   inflating: Wai Final/SegmentationClass/cat.2379.png
#   inflating: Wai Final/SegmentationClass/cat.2380.png
#   inflating: Wai Final/SegmentationClass/cat.2381.png
#   inflating: Wai Final/SegmentationClass/cat.2382.png
#   inflating: Wai Final/SegmentationClass/cat.2383.png
#   inflating: Wai Final/SegmentationClass/cat.2384.png
#   inflating: Wai Final/SegmentationClass/cat.2385.png
#   inflating: Wai Final/SegmentationClass/cat.2386.png
#   inflating: Wai Final/SegmentationClass/cat.2387.png
#   inflating: Wai Final/SegmentationClass/cat.2388.png
#   inflating: Wai Final/SegmentationClass/cat.2389.png
#   inflating: Wai Final/SegmentationClass/cat.2390.png
#   inflating: Wai Final/SegmentationClass/cat.2391.png
#   inflating: Wai Final/SegmentationClass/cat.2392.png
#   inflating: Wai Final/SegmentationClass/cat.2393.png
#   inflating: Wai Final/SegmentationClass/cat.2394.png
#   inflating: Wai Final/SegmentationClass/cat.2395.png
#   inflating: Wai Final/SegmentationClass/cat.2396.png
#   inflating: Wai Final/SegmentationClass/cat.2397.png
#   inflating: Wai Final/SegmentationClass/cat.2398.png
#   inflating: Wai Final/SegmentationClass/cat.2399.png
#   inflating: Wai Final/SegmentationClass/cat.2400.png
#   inflating: Wai Final/SegmentationClass/cat.2401.png
#   inflating: Wai Final/SegmentationClass/cat.2402.png
#   inflating: Wai Final/SegmentationClass/cat.2403.png
#   inflating: Wai Final/SegmentationClass/cat.2404.png
#   inflating: Wai Final/SegmentationClass/cat.2405.png
#   inflating: Wai Final/SegmentationClass/cat.2406.png
#   inflating: Wai Final/SegmentationClass/cat.2407.png
#   inflating: Wai Final/SegmentationClass/cat.2408.png
#   inflating: Wai Final/SegmentationClass/cat.2409.png
#   inflating: Wai Final/SegmentationClass/cat.2410.png
#   inflating: Wai Final/SegmentationClass/cat.2411.png
#   inflating: Wai Final/SegmentationClass/cat.2412.png
#   inflating: Wai Final/SegmentationClass/cat.2413.png
#   inflating: Wai Final/SegmentationClass/cat.2414.png
#   inflating: Wai Final/SegmentationClass/cat.2415.png
#   inflating: Wai Final/SegmentationClass/cat.2416.png
#   inflating: Wai Final/SegmentationClass/cat.2417.png
#   inflating: Wai Final/SegmentationClass/cat.2418.png
#   inflating: Wai Final/SegmentationClass/cat.2419.png
#   inflating: Wai Final/SegmentationClass/cat.2420.png
#   inflating: Wai Final/SegmentationClass/cat.2421.png
#   inflating: Wai Final/SegmentationClass/cat.2422.png
#   inflating: Wai Final/SegmentationClass/cat.2423.png
#   inflating: Wai Final/SegmentationClass/cat.2424.png
#   inflating: Wai Final/SegmentationClass/cat.2425.png
#   inflating: Wai Final/SegmentationClass/cat.2426.png
#   inflating: Wai Final/SegmentationClass/cat.2427.png
#   inflating: Wai Final/SegmentationClass/cat.2428.png
#   inflating: Wai Final/SegmentationClass/cat.2429.png
#   inflating: Wai Final/SegmentationClass/cat.2430.png
#   inflating: Wai Final/SegmentationClass/cat.2431.png
#   inflating: Wai Final/SegmentationClass/cat.2432.png
#   inflating: Wai Final/SegmentationClass/cat.2433.png
#   inflating: Wai Final/SegmentationClass/cat.2434.png
#   inflating: Wai Final/SegmentationClass/cat.2435.png
#   inflating: Wai Final/SegmentationClass/cat.2436.png
#   inflating: Wai Final/SegmentationClass/cat.2437.png
#   inflating: Wai Final/SegmentationClass/cat.2438.png
#   inflating: Wai Final/SegmentationClass/cat.2439.png
#   inflating: Wai Final/SegmentationClass/cat.2440.png
#   inflating: Wai Final/SegmentationClass/cat.2441.png
#   inflating: Wai Final/SegmentationClass/cat.2442.png
#   inflating: Wai Final/SegmentationClass/cat.2443.png
#   inflating: Wai Final/SegmentationClass/cat.2444.png
#   inflating: Wai Final/SegmentationClass/cat.2445.png
#   inflating: Wai Final/SegmentationClass/cat.2446.png
#   inflating: Wai Final/SegmentationClass/cat.2447.png
#   inflating: Wai Final/SegmentationClass/cat.2448.png
#   inflating: Wai Final/SegmentationClass/cat.2449.png
#   inflating: Wai Final/SegmentationClass/cat.2450.png
#   inflating: Wai Final/SegmentationClass/cat.2451.png
#   inflating: Wai Final/SegmentationClass/cat.2452.png
#   inflating: Wai Final/SegmentationClass/cat.2453.png
#   inflating: Wai Final/SegmentationClass/cat.2454.png
#   inflating: Wai Final/SegmentationClass/cat.2455.png
#   inflating: Wai Final/SegmentationClass/cat.2456.png
#   inflating: Wai Final/SegmentationClass/cat.2457.png
#   inflating: Wai Final/SegmentationClass/cat.2458.png
#   inflating: Wai Final/SegmentationClass/cat.2459.png
#   inflating: Wai Final/SegmentationClass/cat.2460.png
#   inflating: Wai Final/SegmentationClass/cat.2461.png
#   inflating: Wai Final/SegmentationClass/cat.2462.png
#   inflating: Wai Final/SegmentationClass/cat.2463.png
#   inflating: Wai Final/SegmentationClass/cat.2464.png
#   inflating: Wai Final/SegmentationClass/cat.2465.png
#   inflating: Wai Final/SegmentationClass/dog.2360.png
#   inflating: Wai Final/SegmentationClass/dog.2361.png
#   inflating: Wai Final/SegmentationClass/dog.2362.png
#   inflating: Wai Final/SegmentationClass/dog.2363.png
#   inflating: Wai Final/SegmentationClass/dog.2364.png
#   inflating: Wai Final/SegmentationClass/dog.2365.png
#   inflating: Wai Final/SegmentationClass/dog.2366.png
#   inflating: Wai Final/SegmentationClass/dog.2367.png
#   inflating: Wai Final/SegmentationClass/dog.2368.png
#   inflating: Wai Final/SegmentationClass/dog.2369.png
#   inflating: Wai Final/SegmentationClass/dog.2370.png
#   inflating: Wai Final/SegmentationClass/dog.2371.png
#   inflating: Wai Final/SegmentationClass/dog.2372.png
#   inflating: Wai Final/SegmentationClass/dog.2373.png
#   inflating: Wai Final/SegmentationClass/dog.2374.png
#   inflating: Wai Final/SegmentationClass/dog.2375.png
#   inflating: Wai Final/SegmentationClass/dog.2376.png
#   inflating: Wai Final/SegmentationClass/dog.2377.png
#   inflating: Wai Final/SegmentationClass/dog.2378.png
#   inflating: Wai Final/SegmentationClass/dog.2379.png
#   inflating: Wai Final/SegmentationClass/dog.2380.png
#   inflating: Wai Final/SegmentationClass/dog.2381.png
#   inflating: Wai Final/SegmentationClass/dog.2382.png
#   inflating: Wai Final/SegmentationClass/dog.2383.png
#   inflating: Wai Final/SegmentationClass/dog.2384.png
#   inflating: Wai Final/SegmentationClass/dog.2385.png
#   inflating: Wai Final/SegmentationClass/dog.2386.png
#   inflating: Wai Final/SegmentationClass/dog.2387.png
#   inflating: Wai Final/SegmentationClass/dog.2388.png
#   inflating: Wai Final/SegmentationClass/dog.2389.png
#   inflating: Wai Final/SegmentationClass/dog.2390.png
#   inflating: Wai Final/SegmentationClass/dog.2391.png
#   inflating: Wai Final/SegmentationClass/dog.2392.png
#   inflating: Wai Final/SegmentationClass/dog.2393.png
#   inflating: Wai Final/SegmentationClass/dog.2394.png
#   inflating: Wai Final/SegmentationClass/dog.2395.png
#   inflating: Wai Final/SegmentationClass/dog.2396.png
#   inflating: Wai Final/SegmentationClass/dog.2397.png
#   inflating: Wai Final/SegmentationClass/dog.2398.png
#   inflating: Wai Final/SegmentationClass/dog.2399.png
#   inflating: Wai Final/SegmentationClass/dog.2400.png
#   inflating: Wai Final/SegmentationClass/dog.2401.png
#   inflating: Wai Final/SegmentationClass/dog.2402.png
#   inflating: Wai Final/SegmentationClass/dog.2403.png
#   inflating: Wai Final/SegmentationClass/dog.2404.png
#   inflating: Wai Final/SegmentationClass/dog.2405.png
#   inflating: Wai Final/SegmentationClass/dog.2406.png
#   inflating: Wai Final/SegmentationClass/dog.2407.png
#   inflating: Wai Final/SegmentationClass/dog.2408.png
#   inflating: Wai Final/SegmentationClass/dog.2409.png
#   inflating: Wai Final/SegmentationClass/dog.2410.png
#   inflating: Wai Final/SegmentationClass/dog.2411.png
#   inflating: Wai Final/SegmentationClass/dog.2412.png
#   inflating: Wai Final/SegmentationClass/dog.2413.png
#   inflating: Wai Final/SegmentationClass/dog.2414.png
#   inflating: Wai Final/SegmentationClass/dog.2415.png
#   inflating: Wai Final/SegmentationClass/dog.2416.png
#   inflating: Wai Final/SegmentationClass/dog.2417.png
#   inflating: Wai Final/SegmentationClass/dog.2418.png
#   inflating: Wai Final/SegmentationClass/dog.2419.png
#   inflating: Wai Final/SegmentationClass/dog.2420.png
#   inflating: Wai Final/SegmentationClass/dog.2421.png
#   inflating: Wai Final/SegmentationClass/dog.2422.png
#   inflating: Wai Final/SegmentationClass/dog.2423.png
#   inflating: Wai Final/SegmentationClass/dog.2424.png
#   inflating: Wai Final/SegmentationClass/dog.2425.png
#   inflating: Wai Final/SegmentationClass/dog.2426.png
#   inflating: Wai Final/SegmentationClass/dog.2427.png
#   inflating: Wai Final/SegmentationClass/dog.2428.png
#   inflating: Wai Final/SegmentationClass/dog.2429.png
#   inflating: Wai Final/SegmentationClass/dog.2430.png
#   inflating: Wai Final/SegmentationClass/dog.2431.png
#   inflating: Wai Final/SegmentationClass/dog.2432.png
#   inflating: Wai Final/SegmentationClass/dog.2433.png
#   inflating: Wai Final/SegmentationClass/dog.2434.png
#   inflating: Wai Final/SegmentationClass/dog.2435.png
#   inflating: Wai Final/SegmentationClass/dog.2436.png
#   inflating: Wai Final/SegmentationClass/dog.2437.png
#   inflating: Wai Final/SegmentationClass/dog.2438.png
#   inflating: Wai Final/SegmentationClass/dog.2439.png
#   inflating: Wai Final/SegmentationClass/dog.2440.png
#   inflating: Wai Final/SegmentationClass/dog.2441.png
#   inflating: Wai Final/SegmentationClass/dog.2442.png
#   inflating: Wai Final/SegmentationClass/dog.2443.png
#   inflating: Wai Final/SegmentationClass/dog.2444.png
#   inflating: Wai Final/SegmentationClass/dog.2445.png
#   inflating: Wai Final/SegmentationClass/dog.2446.png
#   inflating: Wai Final/SegmentationClass/dog.2447.png
#   inflating: Wai Final/SegmentationClass/dog.2448.png
#   inflating: Wai Final/SegmentationClass/dog.2449.png
#   inflating: Wai Final/SegmentationClass/dog.2450.png
#   inflating: Wai Final/SegmentationClass/dog.2451.png
#   inflating: Wai Final/SegmentationClass/dog.2452.png
#   inflating: Wai Final/SegmentationClass/dog.2453.png
#   inflating: Wai Final/SegmentationClass/dog.2454.png
#   inflating: Wai Final/SegmentationClass/dog.2455.png
#   inflating: Wai Final/SegmentationClass/dog.2456.png
#   inflating: Wai Final/SegmentationClass/dog.2457.png
#   inflating: Wai Final/SegmentationClass/dog.2458.png
#   inflating: Wai Final/SegmentationClass/dog.2459.png

# %%
import tensorflow as tf
import os

DATA_DIR = '/content/Wai Final'

IMAGE_DIR = os.path.join(DATA_DIR, 'JPEGImages')
MASK_DIR = os.path.join(DATA_DIR, 'encoded_masks')

# %%
image_filenames = sorted(os.listdir(IMAGE_DIR))
image_paths = [os.path.join(IMAGE_DIR, fname) for fname in image_filenames]

mask_filenames = sorted(os.listdir(MASK_DIR))
mask_paths = [os.path.join(MASK_DIR, fname) for fname in mask_filenames]


# Create the initial dataset of file path pairs
full_dataset = tf.data.Dataset.from_tensor_slices((image_paths, mask_paths))
print(image_paths[0])
print(mask_paths[0])
# Out:
# /content/Wai Final/JPEGImages/cat.2366.jpg
# /content/Wai Final/encoded_masks/cat.2366.png

# %%
DATASET_SIZE = len(image_paths)
TRAIN_SIZE = int(0.8 * DATASET_SIZE) # 80% for training
VAL_SIZE = DATASET_SIZE - TRAIN_SIZE # 20% for validation


full_dataset = full_dataset.shuffle(buffer_size=DATASET_SIZE)

train_dataset = full_dataset.take(TRAIN_SIZE)
val_dataset = full_dataset.skip(TRAIN_SIZE)

print(f"Total examples: {DATASET_SIZE}")
print(f"Training examples: {len(train_dataset)}")
print(f"Validation examples: {len(val_dataset)}")
# Out:
# Total examples: 200
# Training examples: 160
# Validation examples: 40

# %%
IMG_HEIGHT = 128
IMG_WIDTH = 128

# %%
def load_and_preprocess(img_path, label_path):
    # 1. Read and decode the image
    img = tf.io.read_file(img_path)
    img = tf.image.decode_png(img, channels=3)
    img = tf.image.resize(img, [IMG_HEIGHT, IMG_WIDTH])
    # Normalize pixel values to be between 0 and 1
    img = tf.cast(img, tf.float32) / 255.0

    # 2. Read and decode the label (mask)
    label = tf.io.read_file(label_path)
    label = tf.image.decode_png(label, channels=1)
    # Use 'nearest' neighbor resizing for masks to avoid creating new class values
    label = tf.image.resize(label, [IMG_HEIGHT, IMG_WIDTH], method='nearest')

    return img, label

# %%
BATCH_SIZE = 16
BUFFER_SIZE = 200

# %%
train_batches = (
    train_dataset
    .map(load_and_preprocess, num_parallel_calls=tf.data.AUTOTUNE)
    .cache()  # Cache data for faster subsequent epochs
    .shuffle(BUFFER_SIZE)
    .batch(BATCH_SIZE)
    .repeat() # Repeat the dataset indefinitely
    .prefetch(buffer_size=tf.data.AUTOTUNE) # Prepares the next batches while the current one is processed
)

# %%
val_batches = (
    val_dataset
    .map(load_and_preprocess, num_parallel_calls=tf.data.AUTOTUNE)
    .batch(BATCH_SIZE)
    .prefetch(buffer_size=tf.data.AUTOTUNE)
)

# %%
import matplotlib.pyplot as plt
temp_label =None
for images, labels in train_batches.take(1):
    print("\n--- Verifying a batch ---")
    print("Images batch shape:", images.shape)
    print("Labels batch shape:", labels.shape)

    fig, axes = plt.subplots(1, 2, figsize=(10, 5))
    indx = 0

    temp_label = labels[indx]
    axes[0].imshow(images[indx])
    axes[1].imshow(labels[indx],cmap='viridis')
    break
plt.show()
# Out:
# --- Verifying a batch ---
# Images batch shape: (16, 128, 128, 3)
# Labels batch shape: (16, 128, 128, 1)

# %%
import numpy as np
color_value_list = set()
label_numpy = temp_label.numpy()
unique_values = np.unique(label_numpy)
print(unique_values)


for row in range(IMG_WIDTH):
    for col in range(IMG_HEIGHT):
        color_value = label_numpy[row, col][0]
        color_value_list.add(color_value)

print(color_value_list)
# Out:
# [0 1]
# {np.uint8(0), np.uint8(1)}

# %%
import tensorflow as tf
from tensorflow.keras import layers

def build_unet_with_mobilenet(input_shape, num_classes):
    """
    Builds a U-Net model using a pre-trained MobileNetV2 as the encoder.
    (Corrected Version)
    """

    base_model = tf.keras.applications.MobileNetV2(
        input_shape=input_shape,
        include_top=False,
        weights='imagenet'
    )


    layer_names = [
        'block_1_expand_relu',   # 64x64
        'block_3_expand_relu',   # 32x32
        'block_6_expand_relu',   # 16x16
        'block_13_expand_relu',  # 8x8
        'out_relu',              # Bottleneck: 4x4
    ]
    base_model_outputs = [base_model.get_layer(name).output for name in layer_names]

    # Create the feature extraction model (the encoder)
    encoder = tf.keras.Model(inputs=base_model.input, outputs=base_model_outputs, name="encoder")
    encoder.trainable = False



    #  Build the Decoder Path
    inputs = tf.keras.Input(shape=input_shape)
    skips = encoder(inputs)
    x = skips[-1]

    decoder_skips = reversed(skips[:-1])

    for i, skip in enumerate(decoder_skips):
        x = layers.Conv2DTranspose(filters=512 // (2**i), kernel_size=2, strides=2, padding='same')(x)
        x = layers.Concatenate()([x, skip])
        x = layers.Conv2D(filters=512 // (2**i), kernel_size=3, padding='same', activation='relu')(x)
        x = layers.Conv2D(filters=512 // (2**i), kernel_size=3, padding='same', activation='relu')(x)

    # It takes the 64x64 feature map and upsamples it to 128x128.
    outputs = layers.Conv2DTranspose(
        filters=num_classes,
        kernel_size=2,
        strides=2,
        padding='same',
        activation='softmax'  # Apply softmax directly here
    )(x)

    model = tf.keras.Model(inputs=inputs, outputs=outputs)

    return model

# %%
NUM_CLASSES = 3
input_shape = (IMG_HEIGHT, IMG_WIDTH, 3)
model = build_unet_with_mobilenet(input_shape, NUM_CLASSES)
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_128_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ encoder             │ [(None, 64, 64,   │  2,257,984 │ input_layer_1[0]… │
# │ (Functional)        │ 96), (None, 32,   │            │                   │
# │                     │ 32, 144), (None,  │            │                   │
# │                     │ 16, 16, 192),     │            │                   │
# │                     │ (None, 8, 8,      │            │                   │
# │                     │ 576), (None, 4,   │            │                   │
# │                     │ 4, 1280)]         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose    │ (None, 8, 8, 512) │  2,621,952 │ encoder[0][4]     │
# │ (Conv2DTranspose)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 8, 8,      │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 1088)             │            │ encoder[0][3]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 8, 8, 512) │  5,014,016 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 8, 8, 512) │  2,359,808 │ conv2d[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_1  │ (None, 16, 16,    │    524,544 │ conv2d_1[0][0]    │
# │ (Conv2DTranspose)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 16, 16,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 448)              │            │ encoder[0][2]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 16, 16,    │  1,032,448 │ concatenate_1[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 16, 16,    │    590,080 │ conv2d_2[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_2  │ (None, 32, 32,    │    131,200 │ conv2d_3[0][0]    │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 32, 32,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 272)              │            │ encoder[0][1]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 32, 32,    │    313,472 │ concatenate_2[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 32, 32,    │    147,584 │ conv2d_4[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_3  │ (None, 64, 64,    │     32,832 │ conv2d_5[0][0]    │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 64, 64,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 160)              │            │ encoder[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 64, 64,    │     92,224 │ concatenate_3[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 64, 64,    │     36,928 │ conv2d_6[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_4  │ (None, 128, 128,  │        771 │ conv2d_7[0][0]    │
# │ (Conv2DTranspose)   │ 3)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 15,155,843 (57.81 MB)
#  Trainable params: 12,897,859 (49.20 MB)
#  Non-trainable params: 2,257,984 (8.61 MB)

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
EPOCHS = 50
STEPS_PER_EPOCH = len(train_dataset) // BATCH_SIZE
print(STEPS_PER_EPOCH)
# Out:
# 10

# %%
from tensorflow.keras.utils import plot_model

# pip install pydot
# Save model architecture as image
plot_model(model, to_file="tf_lr_model_architecture.png", show_shapes=True, show_layer_names=True)

# %%
lr_scheduler = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.2,
    patience=3,
    min_lr=1e-5
)

history = model.fit(
    train_batches,
    epochs=EPOCHS,
    steps_per_epoch=STEPS_PER_EPOCH,
    validation_data=val_batches,
    callbacks=[lr_scheduler]
)
# Out:
# Epoch 1/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 49s 2s/step - accuracy: 0.4707 - loss: 1.1130 - val_accuracy: 0.6283 - val_loss: 0.9225 - learning_rate: 0.0010
# Epoch 2/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - accuracy: 0.5721 - loss: 0.9631 - val_accuracy: 0.6158 - val_loss: 0.7791 - learning_rate: 0.0010
# Epoch 3/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - accuracy: 0.6027 - loss: 0.8367 - val_accuracy: 0.5901 - val_loss: 0.8526 - learning_rate: 0.0010
# Epoch 4/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - accuracy: 0.6489 - loss: 0.7450 - val_accuracy: 0.6760 - val_loss: 0.7085 - learning_rate: 0.0010
# Epoch 5/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - accuracy: 0.7082 - loss: 0.6560 - val_accuracy: 0.7199 - val_loss: 0.6669 - learning_rate: 0.0010
# Epoch 6/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.7442 - loss: 0.5791 - val_accuracy: 0.7948 - val_loss: 0.5138 - learning_rate: 0.0010
# Epoch 7/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - accuracy: 0.7965 - loss: 0.5090 - val_accuracy: 0.6647 - val_loss: 0.6420 - learning_rate: 0.0010
# Epoch 8/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - accuracy: 0.7331 - loss: 0.5603 - val_accuracy: 0.8311 - val_loss: 0.4812 - learning_rate: 0.0010
# Epoch 9/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.8233 - loss: 0.4927 - val_accuracy: 0.8707 - val_loss: 0.3983 - learning_rate: 0.0010
# Epoch 10/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - accuracy: 0.8784 - loss: 0.3748 - val_accuracy: 0.8854 - val_loss: 0.3491 - learning_rate: 0.0010
# Epoch 11/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - accuracy: 0.8935 - loss: 0.3014 - val_accuracy: 0.8918 - val_loss: 0.2813 - learning_rate: 0.0010
# Epoch 12/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - accuracy: 0.9090 - loss: 0.2474 - val_accuracy: 0.9038 - val_loss: 0.2548 - learning_rate: 0.0010
# Epoch 13/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - accuracy: 0.9221 - loss: 0.2022 - val_accuracy: 0.9055 - val_loss: 0.3690 - learning_rate: 0.0010
# Epoch 14/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - accuracy: 0.9360 - loss: 0.1625 - val_accuracy: 0.9091 - val_loss: 0.2468 - learning_rate: 0.0010
# Epoch 15/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - accuracy: 0.9416 - loss: 0.1457 - val_accuracy: 0.9246 - val_loss: 0.3100 - learning_rate: 0.0010
# Epoch 16/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - accuracy: 0.9514 - loss: 0.1209 - val_accuracy: 0.9425 - val_loss: 0.1638 - learning_rate: 0.0010
# Epoch 17/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - accuracy: 0.9535 - loss: 0.1141 - val_accuracy: 0.9226 - val_loss: 0.4104 - learning_rate: 0.0010
# Epoch 18/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - accuracy: 0.9567 - loss: 0.1074 - val_accuracy: 0.9398 - val_loss: 0.2551 - learning_rate: 0.0010
# Epoch 19/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.9618 - loss: 0.0956 - val_accuracy: 0.9356 - val_loss: 0.3510 - learning_rate: 0.0010
# Epoch 20/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.9654 - loss: 0.0853 - val_accuracy: 0.9350 - val_loss: 0.2433 - learning_rate: 2.0000e-04
# Epoch 21/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - accuracy: 0.9676 - loss: 0.0798 - val_accuracy: 0.9410 - val_loss: 0.2978 - learning_rate: 2.0000e-04
# Epoch 22/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - accuracy: 0.9697 - loss: 0.0757 - val_accuracy: 0.9644 - val_loss: 0.0970 - learning_rate: 2.0000e-04
# Epoch 23/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - accuracy: 0.9707 - loss: 0.0727 - val_accuracy: 0.9449 - val_loss: 0.2807 - learning_rate: 2.0000e-04
# Epoch 24/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - accuracy: 0.9722 - loss: 0.0697 - val_accuracy: 0.9493 - val_loss: 0.3304 - learning_rate: 2.0000e-04
# Epoch 25/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.9729 - loss: 0.0674 - val_accuracy: 0.9635 - val_loss: 0.1016 - learning_rate: 2.0000e-04
# Epoch 26/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.9748 - loss: 0.0630 - val_accuracy: 0.9318 - val_loss: 0.3978 - learning_rate: 4.0000e-05
# Epoch 27/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - accuracy: 0.9745 - loss: 0.0645 - val_accuracy: 0.9470 - val_loss: 0.2199 - learning_rate: 4.0000e-05
# Epoch 28/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - accuracy: 0.9748 - loss: 0.0634 - val_accuracy: 0.9607 - val_loss: 0.1486 - learning_rate: 4.0000e-05
# Epoch 29/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - accuracy: 0.9739 - loss: 0.0643 - val_accuracy: 0.9655 - val_loss: 0.0925 - learning_rate: 1.0000e-05
# Epoch 30/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - accuracy: 0.9743 - loss: 0.0637 - val_accuracy: 0.9625 - val_loss: 0.1153 - learning_rate: 1.0000e-05
# Epoch 31/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - accuracy: 0.9746 - loss: 0.0632 - val_accuracy: 0.9672 - val_loss: 0.1134 - learning_rate: 1.0000e-05
# Epoch 32/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - accuracy: 0.9753 - loss: 0.0617 - val_accuracy: 0.9580 - val_loss: 0.1348 - learning_rate: 1.0000e-05
# Epoch 33/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 92ms/step - accuracy: 0.9755 - loss: 0.0612 - val_accuracy: 0.9421 - val_loss: 0.3151 - learning_rate: 1.0000e-05
# Epoch 34/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - accuracy: 0.9741 - loss: 0.0646 - val_accuracy: 0.9643 - val_loss: 0.1052 - learning_rate: 1.0000e-05
# Epoch 35/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - accuracy: 0.9761 - loss: 0.0598 - val_accuracy: 0.9611 - val_loss: 0.1204 - learning_rate: 1.0000e-05
# Epoch 36/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - accuracy: 0.9752 - loss: 0.0621 - val_accuracy: 0.9525 - val_loss: 0.2270 - learning_rate: 1.0000e-05
# Epoch 37/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - accuracy: 0.9759 - loss: 0.0604 - val_accuracy: 0.9694 - val_loss: 0.0834 - learning_rate: 1.0000e-05
# Epoch 38/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - accuracy: 0.9749 - loss: 0.0632 - val_accuracy: 0.9364 - val_loss: 0.3404 - learning_rate: 1.0000e-05
# Epoch 39/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - accuracy: 0.9754 - loss: 0.0621 - val_accuracy: 0.9652 - val_loss: 0.1558 - learning_rate: 1.0000e-05
# Epoch 40/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - accuracy: 0.9758 - loss: 0.0604 - val_accuracy: 0.9576 - val_loss: 0.1385 - learning_rate: 1.0000e-05
# Epoch 41/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - accuracy: 0.9750 - loss: 0.0626 - val_accuracy: 0.9511 - val_loss: 0.2086 - learning_rate: 1.0000e-05
# Epoch 42/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - accuracy: 0.9759 - loss: 0.0601 - val_accuracy: 0.9634 - val_loss: 0.1222 - learning_rate: 1.0000e-05
# Epoch 43/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - accuracy: 0.9762 - loss: 0.0595 - val_accuracy: 0.9705 - val_loss: 0.0864 - learning_rate: 1.0000e-05
# Epoch 44/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.9750 - loss: 0.0619 - val_accuracy: 0.9516 - val_loss: 0.2154 - learning_rate: 1.0000e-05
# Epoch 45/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - accuracy: 0.9759 - loss: 0.0603 - val_accuracy: 0.9597 - val_loss: 0.1430 - learning_rate: 1.0000e-05
# Epoch 46/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - accuracy: 0.9769 - loss: 0.0582 - val_accuracy: 0.9471 - val_loss: 0.1754 - learning_rate: 1.0000e-05
# Epoch 47/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - accuracy: 0.9756 - loss: 0.0611 - val_accuracy: 0.9575 - val_loss: 0.1672 - learning_rate: 1.0000e-05
# Epoch 48/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - accuracy: 0.9764 - loss: 0.0591 - val_accuracy: 0.9483 - val_loss: 0.3530 - learning_rate: 1.0000e-05
# Epoch 49/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - accuracy: 0.9753 - loss: 0.0620 - val_accuracy: 0.9391 - val_loss: 0.4011 - learning_rate: 1.0000e-05
# Epoch 50/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - accuracy: 0.9761 - loss: 0.0602 - val_accuracy: 0.9671 - val_loss: 0.0942 - learning_rate: 1.0000e-05

# %%
import matplotlib.pyplot as plt


has_validation_data = 'val_loss' in history.history


plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
if has_validation_data:
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
if has_validation_data:
    plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')

plt.tight_layout()
plt.show()

# %%
print("Evaluating model on the test set...")
loss, accuracy = model.evaluate(val_batches)

print(f"\nTest Loss: {loss:.4f}")
print(f"Test Accuracy: {accuracy:.4f}")
# Out:
# Evaluating model on the test set...
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9519 - loss: 0.2366
#
# Test Loss: 0.1871
# Test Accuracy: 0.9580

# %%
model.save('cat_dog_segmentation_unet.keras')

# %%
loaded_model = tf.keras.models.load_model('/content/cat_dog_segmentation_unet.keras')

# %%
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
def model_predict(image_path, model):
    # This must be IDENTICAL to your training preprocessing
    img = tf.io.read_file(image_path)
    img = tf.image.decode_png(img, channels=3)
    img = tf.image.resize(img, [IMG_HEIGHT, IMG_WIDTH])
    img_normalized = tf.cast(img, tf.float32) / 255.0


    img_batch = tf.expand_dims(img_normalized, axis=0)

    # Predict
    predicted_masks = model.predict(img_batch)
    return predicted_masks , img

# %%
def predict_and_visualize(image_path, model):


    predicted_masks,img = model_predict(image_path, model)

    # The output is (1, H, W, num_classes).
    #  We take the argmax along the
    # class axis to get the final mask (1, H, W).
    pred_mask = tf.argmax(predicted_masks, axis=-1)

    # Remove the batch dimension to get a displayable image (H, W)
    pred_mask = pred_mask[0]
    plt.figure(figsize=(12, 6))

    plt.subplot(1, 2, 1)
    plt.title("Input Image")
    # Display the original, un-normalized image
    plt.imshow(tf.keras.utils.array_to_img(img))
    plt.axis('off')

    plt.subplot(1, 2, 2)
    plt.title("Predicted Mask")
    plt.imshow(pred_mask)
    plt.axis('off')

    plt.show()

# %%
test_path = "/content/Wai Final/JPEGImages/dog.2412.jpg"

predict_and_visualize(test_path, loaded_model)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np

def predict_and_show_all_masks(image_path, model, class_encodings):
    """
    Loads an image, gets a prediction, and displays the probability
    mask for every individual class.
    """
    predicted_masks,img = model_predict(image_path, model)


    # --- 3. Visualize the Input and All Masks ---
    num_classes = model.output_shape[-1]

    # Create a figure to display the results
    # We need 1 spot for the input image + num_classes spots for the masks
    plt.figure(figsize=(15, 4 * (num_classes // 3 + 1)))

    # Plot the input image
    plt.subplot(2, 3, 1)
    plt.title("Input Image")
    plt.imshow(tf.keras.utils.array_to_img(img))
    plt.axis('off')

    # Loop through each class and plot its probability mask
    for i in range(num_classes):
        # Extract the mask for the i-th class
        class_mask = predicted_masks[0, :, :, i]

        # Get the class name from our encodings dictionary
        # JSON keys are strings, so we convert the index `i` to a string
        class_name = class_encodings.get(str(i), f"Class {i}")

        plt.subplot(2, 3, i + 2)
        plt.title(f"Mask: {class_name}")
        # Display the mask as a heatmap. 'viridis' is a good colormap for this.
        plt.imshow(class_mask, cmap='viridis')
        plt.axis('off')

    plt.tight_layout()
    plt.show()

# %%
generic_encodings = {str(i): f"Class {i}" for i in range(NUM_CLASSES)}

predict_and_show_all_masks(test_path, loaded_model, generic_encodings)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step

# %%
import numpy as np
import cv2

# 1. Define a color for each of your 5 classes (0 to 4)
COLOR_MAP = np.array([
    [0, 0, 0],       # Class 0: Black (e.g., background)
    [0, 255, 0],     # Class 1: Green
    [255, 0, 0]     # Class 2: Red
], dtype=np.uint8)

def mask_to_rgb(mask, color_map):
    rgb_mask = np.zeros((*mask.shape, 3), dtype=np.uint8)
    for class_idx, color in enumerate(color_map):
        rgb_mask[mask == class_idx] = color
    return rgb_mask


def predict_and_visualize_color(image_path, model, color_map):
    predicted_masks, img = model_predict(image_path, model)
    pred_mask = tf.argmax(predicted_masks, axis=-1)[0].numpy()

    # Convert mask to color
    color_mask = mask_to_rgb(pred_mask, color_map)

    # Convert original image tensor for display
    input_image_numpy = tf.keras.utils.img_to_array(img, dtype=np.uint8)

    # Blend the input image and the color mask for an overlay effect
    overlay = cv2.addWeighted(input_image_numpy, 0.6, color_mask, 0.4, 0)

    # Display the results
    plt.figure(figsize=(18, 6))

    plt.subplot(1, 3, 1)
    plt.title("Input Image")
    plt.imshow(input_image_numpy)
    plt.axis('off')

    plt.subplot(1, 3, 2)
    plt.title("Predicted Color Mask")
    plt.imshow(color_mask)
    plt.axis('off')

    plt.subplot(1, 3, 3)
    plt.title("Overlay Mask")
    plt.imshow(overlay)
    plt.axis('off')

    plt.show()


test_path = "/content/Wai Final/JPEGImages/cat.2369.jpg"
predict_and_visualize_color(test_path, loaded_model, COLOR_MAP)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
