# %%
import tensorflow as tf
import os

# %%
IMAGE_DIR = './data_dataset_voc/JPEGImages'
MASK_DIR = './data_dataset_voc/encoded_masks'

# %%
image_filenames = sorted(os.listdir(IMAGE_DIR))
image_paths = [os.path.join(IMAGE_DIR, fname) for fname in image_filenames]
mask_paths = [os.path.join(MASK_DIR, os.path.splitext(fname)[0] + ".png") for fname in image_filenames]


# Create the initial dataset of file path pairs
full_dataset = tf.data.Dataset.from_tensor_slices((image_paths, mask_paths))

# %%
DATASET_SIZE = len(image_paths)
TRAIN_SIZE = int(0.8 * DATASET_SIZE) # 80% for training
VAL_SIZE = DATASET_SIZE - TRAIN_SIZE # 20% for validation


full_dataset = full_dataset.shuffle(buffer_size=DATASET_SIZE)

train_dataset = full_dataset.take(TRAIN_SIZE)
val_dataset = full_dataset.skip(TRAIN_SIZE)

print(f"Total examples: {DATASET_SIZE}")
print(f"Training examples: {len(train_dataset)}")
print(f"Validation examples: {len(val_dataset)}")
# Out:
# Total examples: 182
# Training examples: 145
# Validation examples: 37

# %%
IMG_HEIGHT = 128
IMG_WIDTH = 128

# %%
def load_and_preprocess(img_path, label_path):
    # 1. Read and decode the image
    img = tf.io.read_file(img_path)
    img = tf.image.decode_png(img, channels=3)
    img = tf.image.resize(img, [IMG_HEIGHT, IMG_WIDTH])
    # Normalize pixel values to be between 0 and 1
    img = tf.cast(img, tf.float32) / 255.0

    # 2. Read and decode the label (mask)
    label = tf.io.read_file(label_path)
    label = tf.image.decode_png(label, channels=1)
    # Use 'nearest' neighbor resizing for masks to avoid creating new class values
    label = tf.image.resize(label, [IMG_HEIGHT, IMG_WIDTH], method='nearest')
    label = tf.cast(label, tf.int32)

    return img, label

# %%
BATCH_SIZE = 8 # Use 8 because of using Transfer Learning
BUFFER_SIZE = 140

# %%
train_batches = (
    train_dataset
    .map(load_and_preprocess, num_parallel_calls=tf.data.AUTOTUNE)
    .cache()  # Cache data for faster subsequent epochs
    .shuffle(BUFFER_SIZE)
    .batch(BATCH_SIZE)
    .repeat() # Repeat the dataset indefinitely
    .prefetch(buffer_size=tf.data.AUTOTUNE) # Prepares the next batches while the current one is processed
)

# %%
val_batches = (
    val_dataset
    .map(load_and_preprocess, num_parallel_calls=tf.data.AUTOTUNE)
    .batch(BATCH_SIZE)
    .prefetch(buffer_size=tf.data.AUTOTUNE)
)

# %%
import matplotlib.pyplot as plt
temp_label =None
for images, labels in train_batches.take(1):
    print("\n--- Verifying a batch ---")
    print("Images batch shape:", images.shape)
    print("Labels batch shape:", labels.shape)

    fig, axes = plt.subplots(1, 2, figsize=(10, 5))
    indx = 0

    temp_label = labels[indx]
    axes[0].imshow(images[indx])
    axes[1].imshow(labels[indx],cmap='viridis')
    break
plt.show()
# Out:
# --- Verifying a batch ---
# Images batch shape: (8, 128, 128, 3)
# Labels batch shape: (8, 128, 128, 1)

# %%
import numpy as np
color_value_list = set()
label_numpy = temp_label.numpy()
unique_values = np.unique(label_numpy)
print(unique_values)


for row in range(IMG_WIDTH):
    for col in range(IMG_HEIGHT):
        color_value = label_numpy[row, col][0]
        color_value_list.add(color_value)

print(color_value_list)
# Out:
# [0 1]
# {np.int32(0), np.int32(1)}

# %%
import tensorflow as tf
from tensorflow.keras import layers

def build_unet_with_mobilenet(input_shape, num_classes):
    base_model = tf.keras.applications.MobileNetV2(
        input_shape=input_shape,
        include_top=False,
        weights='imagenet'
    )

    layer_names = [
        'block_1_expand_relu',   # 64x64
        'block_3_expand_relu',   # 32x32
        'block_6_expand_relu',   # 16x16
        'block_13_expand_relu',  # 8x8
        'out_relu',              # 4x4
    ]
    base_model_outputs = [base_model.get_layer(name).output for name in layer_names]

    encoder = tf.keras.Model(inputs=base_model.input, outputs=base_model_outputs)
    encoder.trainable = False

    # Input
    inputs = tf.keras.Input(shape=input_shape)
    skips = encoder(inputs)
    x = skips[-1]  # Bottleneck

    decoder_skips = reversed(skips[:-1])

    # Decoder
    for i, skip in enumerate(decoder_skips):
        x = layers.Conv2DTranspose(filters=512 // (2**i), kernel_size=2, strides=2, padding='same')(x)
        x = layers.Concatenate()([x, skip])
        x = layers.Conv2D(filters=512 // (2**i), kernel_size=3, padding='same', activation='relu')(x)
        x = layers.Conv2D(filters=512 // (2**i), kernel_size=3, padding='same', activation='relu')(x)

    # Final upsampling to 128x128
    outputs = layers.Conv2DTranspose(
        filters=num_classes,
        kernel_size=2,
        strides=2,
        padding='same',
        activation='softmax'
    )(x)

    model = tf.keras.Model(inputs=inputs, outputs=outputs)
    return model

# %%
NUM_CLASSES = 3
input_shape = (IMG_HEIGHT, IMG_WIDTH, 3)
model = build_unet_with_mobilenet(input_shape, NUM_CLASSES)
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ functional          │ [(None, 64, 64,   │  2,257,984 │ input_layer_1[0]… │
# │ (Functional)        │ 96), (None, 32,   │            │                   │
# │                     │ 32, 144), (None,  │            │                   │
# │                     │ 16, 16, 192),     │            │                   │
# │                     │ (None, 8, 8,      │            │                   │
# │                     │ 576), (None, 4,   │            │                   │
# │                     │ 4, 1280)]         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose    │ (None, 8, 8, 512) │  2,621,952 │ functional[0][4]  │
# │ (Conv2DTranspose)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 8, 8,      │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 1088)             │            │ functional[0][3]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 8, 8, 512) │  5,014,016 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 8, 8, 512) │  2,359,808 │ conv2d[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_1  │ (None, 16, 16,    │    524,544 │ conv2d_1[0][0]    │
# │ (Conv2DTranspose)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 16, 16,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 448)              │            │ functional[0][2]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 16, 16,    │  1,032,448 │ concatenate_1[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 16, 16,    │    590,080 │ conv2d_2[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_2  │ (None, 32, 32,    │    131,200 │ conv2d_3[0][0]    │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 32, 32,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 272)              │            │ functional[0][1]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 32, 32,    │    313,472 │ concatenate_2[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 32, 32,    │    147,584 │ conv2d_4[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_3  │ (None, 64, 64,    │     32,832 │ conv2d_5[0][0]    │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 64, 64,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 160)              │            │ functional[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 64, 64,    │     92,224 │ concatenate_3[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 64, 64,    │     36,928 │ conv2d_6[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_4  │ (None, 128, 128,  │        771 │ conv2d_7[0][0]    │
# │ (Conv2DTranspose)   │ 3)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 15,155,843 (57.81 MB)
#  Trainable params: 12,897,859 (49.20 MB)
#  Non-trainable params: 2,257,984 (8.61 MB)

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
EPOCHS = 50
STEPS_PER_EPOCH = len(train_dataset) // BATCH_SIZE
print(STEPS_PER_EPOCH)
# Out:
# 18

# %%
from tensorflow.keras.utils import plot_model

# pip install pydot
# Save model architecture as image
plot_model(model, to_file="tf_lr_model_architecture.png", show_shapes=True, show_layer_names=True)

# %%
lr_scheduler = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.2,
    patience=3,
    min_lr=1e-6
)

history = model.fit(
    train_batches,
    epochs=EPOCHS,
    steps_per_epoch=STEPS_PER_EPOCH,
    validation_data=val_batches,
    callbacks=[lr_scheduler]
)
# Out:
# Epoch 1/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 15s 613ms/step - accuracy: 0.5653 - loss: 0.9782 - val_accuracy: 0.5797 - val_loss: 0.7782 - learning_rate: 0.0010
# Epoch 2/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 9s 526ms/step - accuracy: 0.5807 - loss: 0.9156 - val_accuracy: 0.5482 - val_loss: 0.9048 - learning_rate: 0.0010
# Epoch 3/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 9s 490ms/step - accuracy: 0.5752 - loss: 0.8211 - val_accuracy: 0.6048 - val_loss: 0.7136 - learning_rate: 0.0010
# Epoch 4/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 9s 503ms/step - accuracy: 0.6011 - loss: 0.7076 - val_accuracy: 0.6743 - val_loss: 0.6852 - learning_rate: 0.0010
# Epoch 5/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 9s 513ms/step - accuracy: 0.7086 - loss: 0.6575 - val_accuracy: 0.6792 - val_loss: 0.6413 - learning_rate: 0.0010
# Epoch 6/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 578ms/step - accuracy: 0.7276 - loss: 0.6483 - val_accuracy: 0.7760 - val_loss: 0.6284 - learning_rate: 0.0010
# Epoch 7/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 11s 622ms/step - accuracy: 0.7476 - loss: 0.5979 - val_accuracy: 0.7540 - val_loss: 0.5599 - learning_rate: 0.0010
# Epoch 8/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 11s 604ms/step - accuracy: 0.7360 - loss: 0.5883 - val_accuracy: 0.7799 - val_loss: 0.5900 - learning_rate: 0.0010
# Epoch 9/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 11s 585ms/step - accuracy: 0.7624 - loss: 0.5558 - val_accuracy: 0.6849 - val_loss: 0.5630 - learning_rate: 0.0010
# Epoch 10/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 573ms/step - accuracy: 0.7525 - loss: 0.5431 - val_accuracy: 0.7380 - val_loss: 0.5030 - learning_rate: 0.0010
# Epoch 11/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 11s 591ms/step - accuracy: 0.7510 - loss: 0.4981 - val_accuracy: 0.7612 - val_loss: 0.5149 - learning_rate: 0.0010
# Epoch 12/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 550ms/step - accuracy: 0.7688 - loss: 0.4532 - val_accuracy: 0.7923 - val_loss: 0.4322 - learning_rate: 0.0010
# Epoch 13/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 565ms/step - accuracy: 0.8063 - loss: 0.3828 - val_accuracy: 0.8206 - val_loss: 0.3948 - learning_rate: 0.0010
# Epoch 14/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 550ms/step - accuracy: 0.8725 - loss: 0.3498 - val_accuracy: 0.8914 - val_loss: 0.2990 - learning_rate: 0.0010
# Epoch 15/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 556ms/step - accuracy: 0.9029 - loss: 0.2776 - val_accuracy: 0.9115 - val_loss: 0.2540 - learning_rate: 0.0010
# Epoch 16/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 11s 617ms/step - accuracy: 0.9004 - loss: 0.2939 - val_accuracy: 0.9027 - val_loss: 0.2593 - learning_rate: 0.0010
# Epoch 17/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 562ms/step - accuracy: 0.9088 - loss: 0.2479 - val_accuracy: 0.8816 - val_loss: 0.3152 - learning_rate: 0.0010
# Epoch 18/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 554ms/step - accuracy: 0.9283 - loss: 0.1932 - val_accuracy: 0.9327 - val_loss: 0.1992 - learning_rate: 0.0010
# Epoch 19/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 565ms/step - accuracy: 0.9411 - loss: 0.1529 - val_accuracy: 0.9162 - val_loss: 0.2163 - learning_rate: 0.0010
# Epoch 20/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 11s 591ms/step - accuracy: 0.9493 - loss: 0.1326 - val_accuracy: 0.9427 - val_loss: 0.1517 - learning_rate: 0.0010
# Epoch 21/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 596ms/step - accuracy: 0.9584 - loss: 0.1088 - val_accuracy: 0.9378 - val_loss: 0.2014 - learning_rate: 0.0010
# Epoch 22/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 11s 621ms/step - accuracy: 0.9563 - loss: 0.1154 - val_accuracy: 0.9538 - val_loss: 0.1254 - learning_rate: 0.0010
# Epoch 23/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 570ms/step - accuracy: 0.9623 - loss: 0.0967 - val_accuracy: 0.9478 - val_loss: 0.1616 - learning_rate: 0.0010
# Epoch 24/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 557ms/step - accuracy: 0.9669 - loss: 0.0841 - val_accuracy: 0.9419 - val_loss: 0.1997 - learning_rate: 0.0010
# Epoch 25/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 557ms/step - accuracy: 0.9690 - loss: 0.0781 - val_accuracy: 0.9558 - val_loss: 0.1532 - learning_rate: 0.0010
# Epoch 26/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 561ms/step - accuracy: 0.9715 - loss: 0.0719 - val_accuracy: 0.9506 - val_loss: 0.1595 - learning_rate: 2.0000e-04
# Epoch 27/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 571ms/step - accuracy: 0.9738 - loss: 0.0655 - val_accuracy: 0.9675 - val_loss: 0.0890 - learning_rate: 2.0000e-04
# Epoch 28/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 558ms/step - accuracy: 0.9743 - loss: 0.0641 - val_accuracy: 0.9419 - val_loss: 0.2282 - learning_rate: 2.0000e-04
# Epoch 29/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 570ms/step - accuracy: 0.9745 - loss: 0.0649 - val_accuracy: 0.9477 - val_loss: 0.2028 - learning_rate: 2.0000e-04
# Epoch 30/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 560ms/step - accuracy: 0.9753 - loss: 0.0623 - val_accuracy: 0.9480 - val_loss: 0.1807 - learning_rate: 2.0000e-04
# Epoch 31/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 563ms/step - accuracy: 0.9760 - loss: 0.0596 - val_accuracy: 0.9504 - val_loss: 0.1867 - learning_rate: 4.0000e-05
# Epoch 32/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 570ms/step - accuracy: 0.9762 - loss: 0.0604 - val_accuracy: 0.9672 - val_loss: 0.1103 - learning_rate: 4.0000e-05
# Epoch 33/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 580ms/step - accuracy: 0.9759 - loss: 0.0606 - val_accuracy: 0.9562 - val_loss: 0.1443 - learning_rate: 4.0000e-05
# Epoch 34/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 580ms/step - accuracy: 0.9769 - loss: 0.0583 - val_accuracy: 0.9648 - val_loss: 0.1085 - learning_rate: 8.0000e-06
# Epoch 35/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 573ms/step - accuracy: 0.9766 - loss: 0.0589 - val_accuracy: 0.9630 - val_loss: 0.1033 - learning_rate: 8.0000e-06
# Epoch 36/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 574ms/step - accuracy: 0.9766 - loss: 0.0586 - val_accuracy: 0.9478 - val_loss: 0.1966 - learning_rate: 8.0000e-06
# Epoch 37/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 580ms/step - accuracy: 0.9764 - loss: 0.0595 - val_accuracy: 0.9669 - val_loss: 0.0982 - learning_rate: 1.6000e-06
# Epoch 38/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 11s 584ms/step - accuracy: 0.9765 - loss: 0.0591 - val_accuracy: 0.9671 - val_loss: 0.0928 - learning_rate: 1.6000e-06
# Epoch 39/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 11s 593ms/step - accuracy: 0.9765 - loss: 0.0591 - val_accuracy: 0.9573 - val_loss: 0.1415 - learning_rate: 1.6000e-06
# Epoch 40/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 598ms/step - accuracy: 0.9767 - loss: 0.0585 - val_accuracy: 0.9620 - val_loss: 0.1178 - learning_rate: 1.0000e-06
# Epoch 41/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 573ms/step - accuracy: 0.9765 - loss: 0.0591 - val_accuracy: 0.9473 - val_loss: 0.1866 - learning_rate: 1.0000e-06
# Epoch 42/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 11s 588ms/step - accuracy: 0.9759 - loss: 0.0606 - val_accuracy: 0.9529 - val_loss: 0.1930 - learning_rate: 1.0000e-06
# Epoch 43/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 11s 588ms/step - accuracy: 0.9771 - loss: 0.0579 - val_accuracy: 0.9719 - val_loss: 0.0784 - learning_rate: 1.0000e-06
# Epoch 44/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 568ms/step - accuracy: 0.9770 - loss: 0.0577 - val_accuracy: 0.9612 - val_loss: 0.1225 - learning_rate: 1.0000e-06
# Epoch 45/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 578ms/step - accuracy: 0.9756 - loss: 0.0613 - val_accuracy: 0.9554 - val_loss: 0.1539 - learning_rate: 1.0000e-06
# Epoch 46/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 577ms/step - accuracy: 0.9768 - loss: 0.0576 - val_accuracy: 0.9570 - val_loss: 0.1476 - learning_rate: 1.0000e-06
# Epoch 47/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 574ms/step - accuracy: 0.9765 - loss: 0.0594 - val_accuracy: 0.9481 - val_loss: 0.1934 - learning_rate: 1.0000e-06
# Epoch 48/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 11s 587ms/step - accuracy: 0.9770 - loss: 0.0576 - val_accuracy: 0.9553 - val_loss: 0.1634 - learning_rate: 1.0000e-06
# Epoch 49/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 577ms/step - accuracy: 0.9764 - loss: 0.0596 - val_accuracy: 0.9479 - val_loss: 0.1943 - learning_rate: 1.0000e-06
# Epoch 50/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 11s 595ms/step - accuracy: 0.9770 - loss: 0.0575 - val_accuracy: 0.9590 - val_loss: 0.1304 - learning_rate: 1.0000e-06

# %%
import matplotlib.pyplot as plt


has_validation_data = 'val_loss' in history.history


plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
if has_validation_data:
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
if has_validation_data:
    plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')

plt.tight_layout()
plt.show()

# %%
print("Evaluating model on the test set...")
loss, accuracy = model.evaluate(val_batches)

print(f"\nTest Loss: {loss:.4f}")
print(f"Test Accuracy: {accuracy:.4f}")
# Out:
# Evaluating model on the test set...
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 158ms/step - accuracy: 0.9586 - loss: 0.1349
#
# Test Loss: 0.1349
# Test Accuracy: 0.9586

# %% [markdown]
# Model Saving and Prediction

# %%
model.save('cats_and_dogs_final_model.keras')

# %%
loaded_model = tf.keras.models.load_model('cats_and_dogs_final_model.keras')

# %%
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
def model_predict(image_path, model):
    # This must be IDENTICAL to your training preprocessing
    img = tf.io.read_file(image_path)
    img = tf.image.decode_png(img, channels=3)
    img = tf.image.resize(img, [IMG_HEIGHT, IMG_WIDTH])
    img_normalized = tf.cast(img, tf.float32) / 255.0


    img_batch = tf.expand_dims(img_normalized, axis=0)

    # Predict
    predicted_masks = model.predict(img_batch)
    return predicted_masks , img

# %%
def predict_and_visualize(image_path, model):


    predicted_masks,img = model_predict(image_path, model)

    # The output is (1, H, W, num_classes).
    #  We take the argmax along the
    # class axis to get the final mask (1, H, W).
    pred_mask = tf.argmax(predicted_masks, axis=-1)

    # Remove the batch dimension to get a displayable image (H, W)
    pred_mask = pred_mask[0]
    plt.figure(figsize=(12, 6))

    plt.subplot(1, 2, 1)
    plt.title("Input Image")
    # Display the original, un-normalized image
    plt.imshow(tf.keras.utils.array_to_img(img))
    plt.axis('off')

    plt.subplot(1, 2, 2)
    plt.title("Predicted Mask")
    plt.imshow(pred_mask)
    plt.axis('off')

    plt.show()

# %%
test_path = "./data_dataset_voc/JPEGImages/dog.4.jpg"
#test_path = "dataset/car-segmentation/images/003.png"

predict_and_visualize(test_path, loaded_model)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np

def predict_and_show_all_masks(image_path, model, class_encodings):
    """
    Loads an image, gets a prediction, and displays the probability
    mask for every individual class.
    """
    predicted_masks,img = model_predict(image_path, model)


    # --- 3. Visualize the Input and All Masks ---
    num_classes = model.output_shape[-1]

    # Create a figure to display the results
    # We need 1 spot for the input image + num_classes spots for the masks
    plt.figure(figsize=(15, 4 * (num_classes // 3 + 1)))

    # Plot the input image
    plt.subplot(2, 3, 1)
    plt.title("Input Image")
    plt.imshow(tf.keras.utils.array_to_img(img))
    plt.axis('off')

    # Loop through each class and plot its probability mask
    for i in range(num_classes):
        # Extract the mask for the i-th class
        class_mask = predicted_masks[0, :, :, i]

        # Get the class name from our encodings dictionary
        # JSON keys are strings, so we convert the index `i` to a string
        class_name = class_encodings.get(str(i), f"Class {i}")

        plt.subplot(2, 3, i + 2)
        plt.title(f"Mask: {class_name}")
        # Display the mask as a heatmap. 'viridis' is a good colormap for this.
        plt.imshow(class_mask, cmap='viridis')
        plt.axis('off')

    plt.tight_layout()
    plt.show()

# %%
generic_encodings = {str(i): f"Class {i}" for i in range(NUM_CLASSES)}

predict_and_show_all_masks(test_path, loaded_model, generic_encodings)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step

# %%
import numpy as np
import cv2

# 1. Define a color for each of your 5 classes (0 to 4)
COLOR_MAP = np.array([
    [0, 0, 0],       # Class 0: Black (e.g., background)
    [255, 0, 0],     # Class 1: Red
    [0, 255, 0],     # Class 2: Green
    [0, 0, 255],     # Class 3: Blue
    [255, 255, 0]    # Class 4: Yellow
], dtype=np.uint8)

def mask_to_rgb(mask, color_map):
    rgb_mask = np.zeros((*mask.shape, 3), dtype=np.uint8)
    for class_idx, color in enumerate(color_map):
        rgb_mask[mask == class_idx] = color
    return rgb_mask


def predict_and_visualize_color(image_path, model, color_map):
    predicted_masks, img = model_predict(image_path, model)
    pred_mask = tf.argmax(predicted_masks, axis=-1)[0].numpy()

    # Convert mask to color
    color_mask = mask_to_rgb(pred_mask, color_map)

    # Convert original image tensor for display
    input_image_numpy = tf.keras.utils.img_to_array(img, dtype=np.uint8)

    # Blend the input image and the color mask for an overlay effect
    overlay = cv2.addWeighted(input_image_numpy, 0.6, color_mask, 0.4, 0)

    # Display the results
    plt.figure(figsize=(18, 6))

    plt.subplot(1, 3, 1)
    plt.title("Input Image")
    plt.imshow(input_image_numpy)
    plt.axis('off')

    plt.subplot(1, 3, 2)
    plt.title("Predicted Color Mask")
    plt.imshow(color_mask)
    plt.axis('off')

    plt.subplot(1, 3, 3)
    plt.title("Overlay Mask")
    plt.imshow(overlay)
    plt.axis('off')

    plt.show()


test_path = "./data_dataset_voc/JPEGImages/cat.1.jpg"
predict_and_visualize_color(test_path, loaded_model, COLOR_MAP)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step
