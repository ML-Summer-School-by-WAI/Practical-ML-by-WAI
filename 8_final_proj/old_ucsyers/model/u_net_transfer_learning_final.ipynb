# %%
import tensorflow as tf
import os
import glob
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate
from tensorflow.keras.models import Model

# %%
tf.test.is_gpu_available()
# Out:
# WARNING:tensorflow:From /tmp/ipython-input-337460670.py:1: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# True

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
DATA_DIR = r'/content/drive/MyDrive/Final_DataSet/U-net dataset/'

IMAGE_DIR = os.path.join(DATA_DIR, 'images/')
MASK_DIR = os.path.join(DATA_DIR, 'masks/')

# %%
image_filenames = sorted(os.listdir(IMAGE_DIR))
image_paths = [os.path.join(IMAGE_DIR, fname) for fname in image_filenames]
mask_paths = [os.path.join(MASK_DIR, fname) for fname in image_filenames]


# Create the initial dataset of file path pairs
full_dataset = tf.data.Dataset.from_tensor_slices((image_paths, mask_paths))

# %%
DATASET_SIZE = len(image_paths)
TRAIN_SIZE = int(0.8 * DATASET_SIZE) # 80% for training
VAL_SIZE = DATASET_SIZE - TRAIN_SIZE # 20% for validation


full_dataset = full_dataset.shuffle(buffer_size=DATASET_SIZE)

train_dataset = full_dataset.take(TRAIN_SIZE)
val_dataset = full_dataset.skip(TRAIN_SIZE)

print(f"Total examples: {DATASET_SIZE}")
print(f"Training examples: {len(train_dataset)}")
print(f"Validation examples: {len(val_dataset)}")
# Out:
# Total examples: 392
# Training examples: 313
# Validation examples: 79

# %%
IMG_HEIGHT = 128
IMG_WIDTH = 128

# %%
def load_and_preprocess(img_path, label_path):
    # 1. Read and decode the image
    img = tf.io.read_file(img_path)
    img = tf.image.decode_png(img, channels=3)
    img = tf.image.resize(img, [IMG_HEIGHT, IMG_WIDTH])
    # Normalize pixel values to be between 0 and 1
    img = tf.cast(img, tf.float32) / 255.0

    # 2. Read and decode the label (mask)
    label = tf.io.read_file(label_path)
    label = tf.image.decode_png(label, channels=1)
    # Use 'nearest' neighbor resizing for masks to avoid creating new class values
    label = tf.image.resize(label, [IMG_HEIGHT, IMG_WIDTH], method='nearest')
    label =tf.cast(label, tf.int32)

    return img, label

# %%
BATCH_SIZE = 8
BUFFER_SIZE = 200

# %%
#Fixedcode

# Get all image files (.jpg)
image_files = sorted(glob.glob(os.path.join(IMAGE_DIR, "*.jpg")))

# Create matching mask paths (.png)
valid_image_paths = []
valid_mask_paths = []
missing_masks = []

for img_path in image_files:
    filename = os.path.basename(img_path)
    name_without_ext = os.path.splitext(filename)[0]  # Remove .jpg extension

    # Create corresponding mask path with .png extension
    mask_path = os.path.join(MASK_DIR, name_without_ext + ".png")

    if os.path.exists(mask_path):
        valid_image_paths.append(img_path)
        valid_mask_paths.append(mask_path)
    else:
        missing_masks.append(filename)

# Create the corrected dataset
train_dataset = tf.data.Dataset.from_tensor_slices((valid_image_paths, valid_mask_paths))

# %%
train_batches = (
    train_dataset
    .map(load_and_preprocess, num_parallel_calls=tf.data.AUTOTUNE)
    .cache()  # Cache data for faster subsequent epochs
    .shuffle(BUFFER_SIZE)
    .batch(BATCH_SIZE)
    .repeat() # Repeat the dataset indefinitely
    .prefetch(buffer_size=tf.data.AUTOTUNE) # Prepares the next batches while the current one is processed
)

# %%
#Fixedcode

from sklearn.model_selection import train_test_split

# Use the corrected paths from earlier
train_imgs, val_imgs, train_masks, val_masks = train_test_split(
    valid_image_paths, valid_mask_paths,
    test_size=0.2, random_state=42
)

# Create corrected dataset
val_dataset = tf.data.Dataset.from_tensor_slices((val_imgs, val_masks))

# %%
val_batches = (
    val_dataset
    .map(load_and_preprocess, num_parallel_calls=tf.data.AUTOTUNE)
    .batch(BATCH_SIZE)
    .prefetch(buffer_size=tf.data.AUTOTUNE)
)

# %%
import matplotlib.pyplot as plt
temp_label =None
for images, labels in train_batches.take(1):
    print("\n--- Verifying a batch ---")
    print("Images batch shape:", images.shape)
    print("Labels batch shape:", labels.shape)

    fig, axes = plt.subplots(1, 2, figsize=(10, 5))
    indx = 0

    temp_label = labels[indx]
    axes[0].imshow(images[indx])
    axes[1].imshow(labels[indx],cmap='viridis')
    break
plt.show()
# Out:
# --- Verifying a batch ---
# Images batch shape: (8, 128, 128, 3)
# Labels batch shape: (8, 128, 128, 1)

# %%
import numpy as np
color_value_list = set()
label_numpy = temp_label.numpy()
unique_values = np.unique(label_numpy)
print(unique_values)


for row in range(IMG_WIDTH):
    for col in range(IMG_HEIGHT):
        color_value = label_numpy[row, col][0]
        color_value_list.add(color_value)

print(color_value_list)
# Out:
# [0 1]
# {np.int32(0), np.int32(1)}

# %% [markdown]
# ## Build the U-Net Model

# %%
import tensorflow as tf
from tensorflow.keras import layers

def build_unet_with_mobilenet(input_shape, num_classes):
    """
    Builds a U-Net model using a pre-trained MobileNetV2 as the encoder.
    (Corrected Version)
    """

    base_model = tf.keras.applications.MobileNetV2(
        input_shape=input_shape,
        include_top=False,
        weights='imagenet'
    )


    layer_names = [
        'block_1_expand_relu',   # 64x64
        'block_3_expand_relu',   # 32x32
        'block_6_expand_relu',   # 16x16
        'block_13_expand_relu',  # 8x8
        'out_relu',              # Bottleneck: 4x4
    ]
    base_model_outputs = [base_model.get_layer(name).output for name in layer_names]

    # Create the feature extraction model (the encoder)
    encoder = tf.keras.Model(inputs=base_model.input, outputs=base_model_outputs, name="encoder")
    encoder.trainable = False



    #  Build the Decoder Path
    inputs = tf.keras.Input(shape=input_shape)
    skips = encoder(inputs)


    x = skips[-1]

    decoder_skips = reversed(skips[:-1])




    for i, skip in enumerate(decoder_skips):
        x = layers.Conv2DTranspose(filters=512 // (2**i), kernel_size=2, strides=2, padding='same')(x)
        x = layers.Concatenate()([x, skip])
        x = layers.Conv2D(filters=512 // (2**i), kernel_size=3, padding='same', activation='relu')(x)
        x = layers.Conv2D(filters=512 // (2**i), kernel_size=3, padding='same', activation='relu')(x)



    # It takes the 64x64 feature map and upsamples it to 128x128.
    outputs = layers.Conv2DTranspose(
        filters=num_classes,
        kernel_size=2,
        strides=2,
        padding='same',
        activation='softmax'  # Apply softmax directly here
    )(x)

    model = tf.keras.Model(inputs=inputs, outputs=outputs)

    return model

# %%
NUM_CLASSES = 3
input_shape = (IMG_HEIGHT, IMG_WIDTH, 3)
model = build_unet_with_mobilenet(input_shape, NUM_CLASSES)
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_128_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ encoder             │ [(None, 64, 64,   │  2,257,984 │ input_layer_1[0]… │
# │ (Functional)        │ 96), (None, 32,   │            │                   │
# │                     │ 32, 144), (None,  │            │                   │
# │                     │ 16, 16, 192),     │            │                   │
# │                     │ (None, 8, 8,      │            │                   │
# │                     │ 576), (None, 4,   │            │                   │
# │                     │ 4, 1280)]         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose    │ (None, 8, 8, 512) │  2,621,952 │ encoder[0][4]     │
# │ (Conv2DTranspose)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 8, 8,      │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 1088)             │            │ encoder[0][3]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 8, 8, 512) │  5,014,016 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 8, 8, 512) │  2,359,808 │ conv2d[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_1  │ (None, 16, 16,    │    524,544 │ conv2d_1[0][0]    │
# │ (Conv2DTranspose)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 16, 16,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 448)              │            │ encoder[0][2]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 16, 16,    │  1,032,448 │ concatenate_1[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 16, 16,    │    590,080 │ conv2d_2[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_2  │ (None, 32, 32,    │    131,200 │ conv2d_3[0][0]    │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 32, 32,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 272)              │            │ encoder[0][1]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 32, 32,    │    313,472 │ concatenate_2[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 32, 32,    │    147,584 │ conv2d_4[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_3  │ (None, 64, 64,    │     32,832 │ conv2d_5[0][0]    │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 64, 64,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 160)              │            │ encoder[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 64, 64,    │     92,224 │ concatenate_3[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 64, 64,    │     36,928 │ conv2d_6[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_4  │ (None, 128, 128,  │        771 │ conv2d_7[0][0]    │
# │ (Conv2DTranspose)   │ 3)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 15,155,843 (57.81 MB)
#  Trainable params: 12,897,859 (49.20 MB)
#  Non-trainable params: 2,257,984 (8.61 MB)

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
EPOCHS = 50
STEPS_PER_EPOCH = len(train_dataset) // BATCH_SIZE
print(STEPS_PER_EPOCH)
# Out:
# 49

# %%
from tensorflow.keras.utils import plot_model

# pip install pydot
# Save model architecture as image
plot_model(model, to_file="tf_lr_model_architecture.png", show_shapes=True, show_layer_names=True)

# %%
lr_scheduler = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.2,
    patience=3,
    min_lr=1e-6
)

history = model.fit(
    train_batches,
    epochs=EPOCHS,
    steps_per_epoch=STEPS_PER_EPOCH,
    validation_data=val_batches,
    callbacks=[lr_scheduler]
)
# Out:
# Epoch 1/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 78s 1s/step - accuracy: 0.5579 - loss: 0.9346 - val_accuracy: 0.6543 - val_loss: 0.9588 - learning_rate: 0.0010
# Epoch 2/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - accuracy: 0.6951 - loss: 0.7337 - val_accuracy: 0.7537 - val_loss: 0.5793 - learning_rate: 0.0010
# Epoch 3/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.7583 - loss: 0.5451 - val_accuracy: 0.8374 - val_loss: 0.4288 - learning_rate: 0.0010
# Epoch 4/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.8443 - loss: 0.3916 - val_accuracy: 0.8495 - val_loss: 0.3981 - learning_rate: 0.0010
# Epoch 5/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - accuracy: 0.8686 - loss: 0.3324 - val_accuracy: 0.8757 - val_loss: 0.3298 - learning_rate: 0.0010
# Epoch 6/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.8848 - loss: 0.2877 - val_accuracy: 0.9088 - val_loss: 0.2363 - learning_rate: 0.0010
# Epoch 7/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - accuracy: 0.9105 - loss: 0.2252 - val_accuracy: 0.9140 - val_loss: 0.2104 - learning_rate: 0.0010
# Epoch 8/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - accuracy: 0.9189 - loss: 0.1977 - val_accuracy: 0.9154 - val_loss: 0.1968 - learning_rate: 0.0010
# Epoch 9/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - accuracy: 0.9220 - loss: 0.1907 - val_accuracy: 0.9286 - val_loss: 0.1789 - learning_rate: 0.0010
# Epoch 10/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - accuracy: 0.9310 - loss: 0.1766 - val_accuracy: 0.9282 - val_loss: 0.1764 - learning_rate: 0.0010
# Epoch 11/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.9336 - loss: 0.1662 - val_accuracy: 0.9428 - val_loss: 0.1381 - learning_rate: 0.0010
# Epoch 12/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - accuracy: 0.9451 - loss: 0.1390 - val_accuracy: 0.9467 - val_loss: 0.1297 - learning_rate: 0.0010
# Epoch 13/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - accuracy: 0.9501 - loss: 0.1248 - val_accuracy: 0.9543 - val_loss: 0.1135 - learning_rate: 0.0010
# Epoch 14/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.9549 - loss: 0.1142 - val_accuracy: 0.9580 - val_loss: 0.1060 - learning_rate: 0.0010
# Epoch 15/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.9581 - loss: 0.1043 - val_accuracy: 0.9619 - val_loss: 0.0965 - learning_rate: 0.0010
# Epoch 16/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - accuracy: 0.9624 - loss: 0.0930 - val_accuracy: 0.9637 - val_loss: 0.0888 - learning_rate: 0.0010
# Epoch 17/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - accuracy: 0.9647 - loss: 0.0877 - val_accuracy: 0.9654 - val_loss: 0.0843 - learning_rate: 0.0010
# Epoch 18/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.9656 - loss: 0.0859 - val_accuracy: 0.9670 - val_loss: 0.0810 - learning_rate: 0.0010
# Epoch 19/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - accuracy: 0.9691 - loss: 0.0774 - val_accuracy: 0.9705 - val_loss: 0.0725 - learning_rate: 0.0010
# Epoch 20/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.9683 - loss: 0.0779 - val_accuracy: 0.9722 - val_loss: 0.0687 - learning_rate: 0.0010
# Epoch 21/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - accuracy: 0.9722 - loss: 0.0684 - val_accuracy: 0.9722 - val_loss: 0.0672 - learning_rate: 0.0010
# Epoch 22/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - accuracy: 0.9740 - loss: 0.0632 - val_accuracy: 0.9727 - val_loss: 0.0675 - learning_rate: 0.0010
# Epoch 23/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.9744 - loss: 0.0624 - val_accuracy: 0.9764 - val_loss: 0.0572 - learning_rate: 0.0010
# Epoch 24/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - accuracy: 0.9767 - loss: 0.0566 - val_accuracy: 0.9766 - val_loss: 0.0567 - learning_rate: 0.0010
# Epoch 25/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - accuracy: 0.9761 - loss: 0.0585 - val_accuracy: 0.9763 - val_loss: 0.0583 - learning_rate: 0.0010
# Epoch 26/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.9755 - loss: 0.0598 - val_accuracy: 0.9767 - val_loss: 0.0588 - learning_rate: 0.0010
# Epoch 27/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - accuracy: 0.9774 - loss: 0.0557 - val_accuracy: 0.9705 - val_loss: 0.0728 - learning_rate: 0.0010
# Epoch 28/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 51ms/step - accuracy: 0.9748 - loss: 0.0620 - val_accuracy: 0.9785 - val_loss: 0.0512 - learning_rate: 2.0000e-04
# Epoch 29/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.9805 - loss: 0.0470 - val_accuracy: 0.9816 - val_loss: 0.0446 - learning_rate: 2.0000e-04
# Epoch 30/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.9820 - loss: 0.0434 - val_accuracy: 0.9824 - val_loss: 0.0422 - learning_rate: 2.0000e-04
# Epoch 31/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - accuracy: 0.9834 - loss: 0.0402 - val_accuracy: 0.9834 - val_loss: 0.0400 - learning_rate: 2.0000e-04
# Epoch 32/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - accuracy: 0.9837 - loss: 0.0394 - val_accuracy: 0.9841 - val_loss: 0.0385 - learning_rate: 2.0000e-04
# Epoch 33/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - accuracy: 0.9845 - loss: 0.0374 - val_accuracy: 0.9846 - val_loss: 0.0370 - learning_rate: 2.0000e-04
# Epoch 34/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - accuracy: 0.9852 - loss: 0.0359 - val_accuracy: 0.9852 - val_loss: 0.0358 - learning_rate: 2.0000e-04
# Epoch 35/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.9856 - loss: 0.0352 - val_accuracy: 0.9858 - val_loss: 0.0345 - learning_rate: 2.0000e-04
# Epoch 36/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.9862 - loss: 0.0336 - val_accuracy: 0.9862 - val_loss: 0.0336 - learning_rate: 2.0000e-04
# Epoch 37/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.9866 - loss: 0.0325 - val_accuracy: 0.9867 - val_loss: 0.0324 - learning_rate: 2.0000e-04
# Epoch 38/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - accuracy: 0.9867 - loss: 0.0324 - val_accuracy: 0.9870 - val_loss: 0.0317 - learning_rate: 2.0000e-04
# Epoch 39/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.9873 - loss: 0.0311 - val_accuracy: 0.9875 - val_loss: 0.0307 - learning_rate: 2.0000e-04
# Epoch 40/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - accuracy: 0.9879 - loss: 0.0296 - val_accuracy: 0.9878 - val_loss: 0.0297 - learning_rate: 2.0000e-04
# Epoch 41/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - accuracy: 0.9882 - loss: 0.0288 - val_accuracy: 0.9882 - val_loss: 0.0289 - learning_rate: 2.0000e-04
# Epoch 42/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - accuracy: 0.9883 - loss: 0.0286 - val_accuracy: 0.9881 - val_loss: 0.0293 - learning_rate: 2.0000e-04
# Epoch 43/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - accuracy: 0.9885 - loss: 0.0280 - val_accuracy: 0.9884 - val_loss: 0.0284 - learning_rate: 2.0000e-04
# Epoch 44/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.9888 - loss: 0.0275 - val_accuracy: 0.9888 - val_loss: 0.0278 - learning_rate: 2.0000e-04
# Epoch 45/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - accuracy: 0.9892 - loss: 0.0266 - val_accuracy: 0.9892 - val_loss: 0.0266 - learning_rate: 2.0000e-04
# Epoch 46/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - accuracy: 0.9891 - loss: 0.0265 - val_accuracy: 0.9893 - val_loss: 0.0263 - learning_rate: 2.0000e-04
# Epoch 47/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.9899 - loss: 0.0249 - val_accuracy: 0.9891 - val_loss: 0.0264 - learning_rate: 2.0000e-04
# Epoch 48/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - accuracy: 0.9897 - loss: 0.0252 - val_accuracy: 0.9897 - val_loss: 0.0255 - learning_rate: 2.0000e-04
# Epoch 49/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.9898 - loss: 0.0251 - val_accuracy: 0.9901 - val_loss: 0.0245 - learning_rate: 2.0000e-04
# Epoch 50/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.9903 - loss: 0.0237 - val_accuracy: 0.9899 - val_loss: 0.0247 - learning_rate: 2.0000e-04

# %%
import matplotlib.pyplot as plt


has_validation_data = 'val_loss' in history.history


plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
if has_validation_data:
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
if has_validation_data:
    plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')

plt.tight_layout()
plt.show()

# %%
print("Evaluating model on the test set...")
loss, accuracy = model.evaluate(val_batches)

print(f"\nTest Loss: {loss:.4f}")
print(f"Test Accuracy: {accuracy:.4f}")
# Out:
# Evaluating model on the test set...
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9897 - loss: 0.0252
#
# Test Loss: 0.0247
# Test Accuracy: 0.9899

# %% [markdown]
# ### Model Saving and Prediction

# %%
model.save('final_model.keras')

# %%
loaded_model = tf.keras.models.load_model('final_model.keras')

# %%
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
def model_predict(image_path, model):
    # This must be IDENTICAL to your training preprocessing
    img = tf.io.read_file(image_path)
    img = tf.image.decode_png(img, channels=3)
    img = tf.image.resize(img, [IMG_HEIGHT, IMG_WIDTH])
    img_normalized = tf.cast(img, tf.float32) / 255.0


    img_batch = tf.expand_dims(img_normalized, axis=0)

    # Predict
    predicted_masks = model.predict(img_batch)
    return predicted_masks , img

# %%
def predict_and_visualize(image_path, model):


    predicted_masks,img = model_predict(image_path, model)

    # The output is (1, H, W, num_classes).
    #  We take the argmax along the
    # class axis to get the final mask (1, H, W).
    pred_mask = tf.argmax(predicted_masks, axis=-1)

    # Remove the batch dimension to get a displayable image (H, W)
    pred_mask = pred_mask[0]
    plt.figure(figsize=(12, 6))

    plt.subplot(1, 2, 1)
    plt.title("Input Image")
    # Display the original, un-normalized image
    plt.imshow(tf.keras.utils.array_to_img(img))
    plt.axis('off')

    plt.subplot(1, 2, 2)
    plt.title("Predicted Mask")
    plt.imshow(pred_mask)
    plt.axis('off')

    plt.show()

# %%
test_path = "/content/drive/MyDrive/Final_DataSet/U-net dataset/images/cat.620.jpg"
#test_path = "dataset/car-segmentation/images/003.png"

predict_and_visualize(test_path, loaded_model)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 12s 12s/step

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np

def predict_and_show_all_masks(image_path, model, class_encodings):
    """
    Loads an image, gets a prediction, and displays the probability
    mask for every individual class.
    """
    predicted_masks,img = model_predict(image_path, model)


    # --- 3. Visualize the Input and All Masks ---
    num_classes = model.output_shape[-1]

    # Create a figure to display the results
    # We need 1 spot for the input image + num_classes spots for the masks
    plt.figure(figsize=(15, 4 * (num_classes // 3 + 1)))

    # Plot the input image
    plt.subplot(2, 3, 1)
    plt.title("Input Image")
    plt.imshow(tf.keras.utils.array_to_img(img))
    plt.axis('off')

    # Loop through each class and plot its probability mask
    for i in range(num_classes):
        # Extract the mask for the i-th class
        class_mask = predicted_masks[0, :, :, i]

        # Get the class name from our encodings dictionary
        # JSON keys are strings, so we convert the index `i` to a string
        class_name = class_encodings.get(str(i), f"Class {i}")

        plt.subplot(2, 3, i + 2)
        plt.title(f"Mask: {class_name}")
        # Display the mask as a heatmap. 'viridis' is a good colormap for this.
        plt.imshow(class_mask, cmap='viridis')
        plt.axis('off')

    plt.tight_layout()
    plt.show()

# %%
generic_encodings = {str(i): f"Class {i}" for i in range(NUM_CLASSES)}

predict_and_show_all_masks(test_path, loaded_model, generic_encodings)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step

# %%
import numpy as np
import cv2

# 1. Define a color for each of your 5 classes (0 to 4)
COLOR_MAP = np.array([
    [0, 0, 0],       # Class 0: Black (e.g., background)
    [255, 0, 0],     # Class 1: Red
    [0, 255, 0],     # Class 2: Green
    [0, 0, 255],     # Class 3: Blue
    [255, 255, 0]    # Class 4: Yellow
], dtype=np.uint8)

def mask_to_rgb(mask, color_map):
    rgb_mask = np.zeros((*mask.shape, 3), dtype=np.uint8)
    for class_idx, color in enumerate(color_map):
        rgb_mask[mask == class_idx] = color
    return rgb_mask


def predict_and_visualize_color(image_path, model, color_map):
    predicted_masks, img = model_predict(image_path, model)
    pred_mask = tf.argmax(predicted_masks, axis=-1)[0].numpy()

    # Convert mask to color
    color_mask = mask_to_rgb(pred_mask, color_map)

    # Convert original image tensor for display
    input_image_numpy = tf.keras.utils.img_to_array(img, dtype=np.uint8)

    # Blend the input image and the color mask for an overlay effect
    overlay = cv2.addWeighted(input_image_numpy, 0.6, color_mask, 0.4, 0)

    # Display the results
    plt.figure(figsize=(18, 6))

    plt.subplot(1, 3, 1)
    plt.title("Input Image")
    plt.imshow(input_image_numpy)
    plt.axis('off')

    plt.subplot(1, 3, 2)
    plt.title("Predicted Color Mask")
    plt.imshow(color_mask)
    plt.axis('off')

    plt.subplot(1, 3, 3)
    plt.title("Overlay Mask")
    plt.imshow(overlay)
    plt.axis('off')

    plt.show()


test_path = "/content/drive/MyDrive/Final_DataSet/U-net dataset/images/cat.620.jpg"
predict_and_visualize_color(test_path, loaded_model, COLOR_MAP)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
